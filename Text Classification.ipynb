# %%
import random
import nltk
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

# %%
# shuffle the documents
random.shuffle(documents)

# %%
all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())
    
print(all_words[0])
all_words = nltk.FreqDist(all_words)

print('Most common words: {}'.format(all_words.most_common(15)))
print('The word happy: {}'.format(all_words["happy"]))
# Out:
# plot
# Most common words: [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595)]
# The word happy: 215

# %%
# We'll use the 4000 most common words as features
print(len(all_words))
word_features = list(all_words.keys())[:4000]
len(word_features)
# Out:
# 39768
# 4000

# %%
# The find_features function will determine which of the 3000 word features are contained in the review
def find_features(document):
    words = set(document)
  
    features = {}
    for w in word_features:
        features[w] = (w in words)
   # print(features)
    return features

# %%
# Lets use an example from a negative review
features = find_features(movie_reviews.words('neg/cv000_29416.txt'))
for key, value in features.items():
    if value == True:
        print (key)
# Out:
# downshifts
# package
# deal
# before
# throughout
# her
# actors
# cool
# people
# need
# start
# new
# problem
# playing
# t
# make
# correctly
# drive
# good
# guess
# neighborhood
# turning
# little
# seems
# lazy
# sitting
# came
# us
# bad
# but
# character
# generally
# trying
# accident
# things
# couples
# video
# horror

# %%
# Now lets do it for all the documents
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %%
featuresets[0]
# Out:
# ({'sacked': False,
#   'cap': False,
#   '007': False,
#   'es': False,
#   'delpy': False,
#   'belittling': False,
#   'goodwin': False,
#   'sharp': False,
#   'cites': False,
#   'flank': False,
#   'crue': False,
#   'fervour': False,
#   '_real_': False,
#   'card': False,
#   'insinuating': False,
#   'popeye': False,
#   'base': False,
#   'absolut': False,
#   'taj': False,
#   'piggy': False,
#   '_halloween_': False,
#   'dysfuntion': False,
#   'dubbing': False,
#   'feely': False,
#   'expansive': False,
#   'markedly': False,
#   'blink': False,
#   'nominees': False,
#   'willis': False,
#   'understand': False,
#   'displaced': False,
#   'extraction': False,
#   'flanked': False,
#   'unchanged': False,
#   'massachusetts': False,
#   'miko': False,
#   'xvi': False,
#   'superimposed': False,
#   'enthusiasts': False,
#   'lambs': False,
#   'relaxes': False,
#   'providing': False,
#   'padding': False,
#   'hairline': False,
#   'vicki': False,
#   'slooooow': False,
#   'warda': False,
#   'rebirth': False,
#   'vcr': False,
#   'parading': False,
#   'animalities': False,
#   'ordeals': False,
#   'devine': False,
#   'wiped': False,
#   'grates': False,
#   'drake': False,
#   'ribs': False,
#   'verbalized': False,
#   'dispite': False,
#   'plaudits': False,
#   'reminisces': False,
#   'pug': False,
#   'downshifts': False,
#   'barbarity': False,
#   'sue': False,
#   'korngold': False,
#   'passover': False,
#   'invisibility': False,
#   'attacked': False,
#   'charme': False,
#   'taciturn': False,
#   'lopez': False,
#   'novicorp': False,
#   'inhibit': False,
#   'lessen': False,
#   'manhoff': False,
#   'hurls': False,
#   'semite': False,
#   'insist': False,
#   'recoup': False,
#   'earful': False,
#   'offensiveness': False,
#   'classified': False,
#   'sloppiness': False,
#   'package': False,
#   'holding': False,
#   'yesterday': False,
#   'prolonged': False,
#   'scintilla': False,
#   'rise': False,
#   'nhu': False,
#   'dudes': False,
#   'woken': False,
#   'battle': False,
#   'result': False,
#   'bout': False,
#   'kings': False,
#   'andromeda': False,
#   'downloading': False,
#   'mimmo': False,
#   'breeth': False,
#   'enigmatical': False,
#   'peeing': False,
#   'ramifications': False,
#   'tipsy': False,
#   'leick': False,
#   'catty': False,
#   'sandbox': False,
#   'smaller': False,
#   'seductiveness': False,
#   'mindset': False,
#   'poachers': False,
#   'kyra': False,
#   'deal': False,
#   'statham': False,
#   'dizzying': False,
#   'manufacturer': False,
#   'assassinated': False,
#   'desintegration': False,
#   'theorists': False,
#   'beals': False,
#   'congo': False,
#   'noah': False,
#   'cockney': False,
#   'baywatch': False,
#   'crisis': False,
#   'stemming': False,
#   'holm': False,
#   'interrogated': False,
#   'ecologist': False,
#   'slug': False,
#   'elias': False,
#   'unexpectantly': False,
#   'mcdowall': False,
#   'bernstein': False,
#   'comaprison': False,
#   'manned': False,
#   'hedonism': False,
#   'cinematographers': False,
#   'aloud': False,
#   'subvert': False,
#   'kasinsky': False,
#   'resorts': False,
#   'buddie': False,
#   'ramen': False,
#   'deception': False,
#   'magdelene': False,
#   'starbuck': False,
#   'geographical': False,
#   'noteriaty': False,
#   'polo': False,
#   'allison': False,
#   'truth': False,
#   'brutality': False,
#   'before': False,
#   'veruca': False,
#   'workmates': False,
#   'revelation': False,
#   'shifted': False,
#   'intuitively': False,
#   '254': False,
#   'clinic': False,
#   'roomie': False,
#   'noni': False,
#   'dives': False,
#   'videodrome': False,
#   'miracle': False,
#   'myrlie': False,
#   'inhibits': False,
#   'oxide': False,
#   '500th': False,
#   'rotting': False,
#   'pincus': False,
#   'replicas': False,
#   'journeying': False,
#   'measurements': False,
#   'prattle': False,
#   'smarter': False,
#   'adjust': False,
#   'blimp': False,
#   'babs': False,
#   'stifle': False,
#   'herself': False,
#   'dugan': False,
#   'r2d2': False,
#   'bramon': False,
#   'fiddles': False,
#   'subordinate': False,
#   'fourth': False,
#   'cole': False,
#   'horseracing': False,
#   'bewildering': False,
#   'chapped': False,
#   'descending': False,
#   'jensen': False,
#   '51st': False,
#   'saver': False,
#   'dynamites': False,
#   'scathing': False,
#   'stroll': False,
#   'dubey': False,
#   'zigs': False,
#   'willem': False,
#   'calitri': False,
#   'boaz': False,
#   '1983': False,
#   'palpitation': False,
#   'barksdale': False,
#   'scorces': False,
#   'acclaimed': False,
#   'supercode': False,
#   'foulmouthed': False,
#   'minelli': False,
#   'defiance': False,
#   'sweaters': False,
#   'fang': False,
#   'bowels': False,
#   'macnicol': False,
#   'endless': False,
#   'throughout': False,
#   'repulse': False,
#   'priivate': False,
#   'killed': False,
#   'assimilation': False,
#   '310': False,
#   'bluntly': False,
#   'rebuild': False,
#   'samurai': False,
#   'static': False,
#   'brosnon': False,
#   'benefited': False,
#   'mandated': False,
#   'dynamite': False,
#   'wherewithal': False,
#   'overdramaticizes': False,
#   'vaginal': False,
#   'epitaph': False,
#   'mentioned': False,
#   'fail': False,
#   'cargo': False,
#   'sewing': False,
#   'gazillion': False,
#   'mocked': False,
#   'tramp': False,
#   'garde': False,
#   'vagrants': False,
#   'hardford': False,
#   'plumets': False,
#   'themed': False,
#   'primer': False,
#   'microscope': False,
#   'rachmaninov': False,
#   'leder': False,
#   'f': False,
#   'regression': False,
#   'goes': True,
#   'cranked': False,
#   'ninety': False,
#   'interpreted': False,
#   'trumbull': False,
#   'brush': False,
#   'medicated': False,
#   'stub': False,
#   'folktale': False,
#   'enthusiastically': False,
#   'saunder': False,
#   'her': True,
#   'suffrage': False,
#   'famished': False,
#   'rome': False,
#   'vaudeville': False,
#   'retitle': False,
#   'paints': False,
#   'democrats': False,
#   'dextrous': False,
#   'forthright': False,
#   'karloff': False,
#   'snarl': False,
#   'aalyah': False,
#   'columbo': False,
#   'diesl': False,
#   'charred': False,
#   'museums': False,
#   'washed': False,
#   'landing': False,
#   'levien': False,
#   'relentlessy': False,
#   'notifying': False,
#   'arnold': False,
#   'dafoe': False,
#   'daddies': False,
#   'pope': False,
#   'martinis': False,
#   'handlers': False,
#   'debussy': False,
#   'dense': False,
#   'megahit': False,
#   'panel': False,
#   'roars': False,
#   'nyah': False,
#   'attempted': False,
#   'learning': False,
#   'guides': False,
#   'novels': False,
#   'northwestern': False,
#   'smirked': False,
#   'chiseled': False,
#   'extraordinaire': False,
#   'thwart': False,
#   'voodoo': False,
#   'camel': False,
#   'humanizes': False,
#   'engines': False,
#   'twentysomethings': False,
#   'nosedives': False,
#   'eszterhas': False,
#   'eamonn': False,
#   'yar': False,
#   'disease': False,
#   'stiers': False,
#   'butt': False,
#   'bluejeans': False,
#   'visitation': False,
#   'minors': False,
#   'egocentric': False,
#   'creations': False,
#   'profanity': False,
#   'naturalistically': False,
#   'crack': False,
#   'greenery': False,
#   'daydreams': False,
#   'determines': False,
#   'phil': False,
#   'tiffany': False,
#   'laboring': False,
#   'measurement': False,
#   'waded': False,
#   'outset': False,
#   'loving': False,
#   'mcallister': False,
#   'bardsley': False,
#   'josh': False,
#   'waystation': False,
#   'gained': False,
#   'slated': False,
#   'archbishop': False,
#   'betterment': False,
#   'naoki': False,
#   'recluse': False,
#   'cruises': False,
#   'vida': False,
#   'neglectful': False,
#   'glimpsed': False,
#   'thumper': False,
#   'fielding': False,
#   'hint': False,
#   'compete': False,
#   '999': False,
#   'existence': False,
#   'red': False,
#   'pouts': False,
#   'exposes': False,
#   'splashy': False,
#   'anymore': False,
#   'seismic': False,
#   'tentacles': False,
#   'tug': False,
#   'mitchell': False,
#   'tylenol': False,
#   '00': False,
#   'dueling': False,
#   '640': False,
#   'allergy': False,
#   'masterminds': False,
#   'stirring': False,
#   'eaten': False,
#   'chilled': False,
#   'nihilistic': False,
#   'pects': False,
#   'crassly': False,
#   'gunshots': False,
#   'cooder': False,
#   'slightest': False,
#   'resigned': False,
#   'trusting': False,
#   'tissue': False,
#   'protestor': False,
#   'yankee': False,
#   'harrassing': False,
#   'gyrating': False,
#   'shipwreck': False,
#   'wartime': False,
#   'prostitution': False,
#   'supermodels': False,
#   'lasser': False,
#   'refrain': False,
#   'debris': False,
#   'aissa': False,
#   'jimmi': False,
#   'synonyms': False,
#   'bureaucrat': False,
#   'escadapes': False,
#   'waterworks': False,
#   'brownlee': False,
#   'msnbc': False,
#   'belloq': False,
#   'blackboards': False,
#   'pulverizes': False,
#   'dah': False,
#   'audible': False,
#   'successes': False,
#   'kenner': False,
#   'deprive': False,
#   'mekum': False,
#   'sweet': False,
#   'blam': False,
#   'mosley': False,
#   'dea': False,
#   'actors': False,
#   'torn': False,
#   'nova': False,
#   'heir': False,
#   'magritte': False,
#   'understated': False,
#   'harbours': False,
#   'casualties': False,
#   'pow': False,
#   'unnecessarily': False,
#   'sunbathing': False,
#   'johnnie': False,
#   'plunging': False,
#   'schutze': False,
#   'brable': False,
#   'mightily': False,
#   'sympathizers': False,
#   'grotesque': False,
#   'silhouetted': False,
#   'eloquent': False,
#   'backstabbing': False,
#   'batarangs': False,
#   'ted': False,
#   'lynskey': False,
#   'paved': False,
#   'juggles': False,
#   'lows': False,
#   'central_': False,
#   'nomination': False,
#   'backpacks': False,
#   'physicfirst': False,
#   'homeland': False,
#   'fingerprints': False,
#   'panties': False,
#   'copulation': False,
#   'jobs': False,
#   'announced': False,
#   'underlings': False,
#   'disaster_': False,
#   'mozzell': False,
#   'recognizable': False,
#   'dramatization': False,
#   'alphonsia': False,
#   'stemmed': False,
#   'coaxed': False,
#   'cloony': False,
#   'cannom': False,
#   'hong': False,
#   'afro': False,
#   'endlessly': False,
#   'miners': False,
#   'brace': False,
#   'tidal': False,
#   'revisited': False,
#   'overexaggerant': False,
#   'eliminate': False,
#   'slimming': False,
#   'stealthy': False,
#   'organized': False,
#   'burners': False,
#   'characterize': False,
#   'interview': False,
#   'blowing': False,
#   'hygienists': False,
#   'prop': False,
#   'reoccurrence': False,
#   'senseful': False,
#   'babble': False,
#   'obsessions': False,
#   'laundry': False,
#   'meaningless': False,
#   'catatonia': False,
#   'benecio': False,
#   'carey': False,
#   'allyson': False,
#   'picker': False,
#   'manna': False,
#   'vore': False,
#   'justify': False,
#   'customers': False,
#   'bragging': False,
#   'cocaine': False,
#   'pacifier': False,
#   'krupa': False,
#   'outsiders': False,
#   'truely': False,
#   'ugly': False,
#   'rowlands': False,
#   'negating': False,
#   'adroitly': False,
#   'impregnation': False,
#   'marion': False,
#   'magazines': False,
#   'gilled': False,
#   'believably': False,
#   'delude': False,
#   'finesse': False,
#   'connoisseurs': False,
#   'sufficiently': False,
#   'nts': False,
#   'lister': False,
#   'roz': False,
#   'nicknames': False,
#   'cool': False,
#   'choderlos': False,
#   'adrift': False,
#   'derived': False,
#   'pt': False,
#   'penal': False,
#   'moist': False,
#   'tiny': False,
#   'dryer': False,
#   'purchased': False,
#   'analysts': False,
#   'pastiche': False,
#   'krypton': False,
#   'wrongs': False,
#   'voyeuristically': False,
#   'vat': False,
#   'bilk': False,
#   'initiatives': False,
#   'omnivorous': False,
#   'heartland': False,
#   'maniacally': False,
#   'hattie': False,
#   'yearn': False,
#   'romanctic': False,
#   'administering': False,
#   'captains': False,
#   'yogi': False,
#   'tubes': False,
#   'prominent': False,
#   'dog': False,
#   'people': False,
#   'digging': False,
#   'diffuse': False,
#   'spree': False,
#   'quest': False,
#   'dichotomy': False,
#   'lining': False,
#   'goer': False,
#   'suzanne': False,
#   'arrest': False,
#   'fog': False,
#   'malik': False,
#   'trunks': False,
#   'weaves': False,
#   'pensacola': False,
#   'bushes': False,
#   'mannequins': False,
#   'electrocution': False,
#   'zerd': False,
#   'steenburgen': False,
#   'hauls': False,
#   'destruction': False,
#   'worshipping': False,
#   'tests': False,
#   'cigarrettes': False,
#   'stucker': False,
#   'funnel': False,
#   'armor': False,
#   'sulking': False,
#   'cooperative': False,
#   'isacsson': False,
#   'sender': False,
#   'bayard': False,
#   'squinting': False,
#   'electrical': False,
#   'cliques': False,
#   'procedures': False,
#   'factory': False,
#   'rifkin': False,
#   'amply': False,
#   'dully': False,
#   'pierces': False,
#   'funnery': False,
#   'nirvana': False,
#   'juries': False,
#   'bluer': False,
#   'heaed': False,
#   'illogic': False,
#   'saffron': False,
#   'shrouded': False,
#   'cheats': False,
#   'ungainly': False,
#   'extinct': False,
#   'dmx': False,
#   'shou': False,
#   'marco': False,
#   'accomplished': False,
#   'judith': False,
#   'rewrites': False,
#   'pander': False,
#   'knutt': False,
#   'tardiness': False,
#   'counterfeiters': False,
#   'guccione': False,
#   'incorporated': False,
#   'transplanted': False,
#   'mysterty': False,
#   '1773': False,
#   'beachwalkers': False,
#   '1955': False,
#   'jamie': False,
#   'tweeder': False,
#   'time': False,
#   'spaceship': False,
#   'fiasco': False,
#   'ferrara': False,
#   'slackness': False,
#   'devise': False,
#   'jealous': False,
#   'synopsis': False,
#   'pilson': False,
#   'bargained': False,
#   'bucks': False,
#   'commandeer': False,
#   'beauteous': False,
#   'reflects': False,
#   'extort': False,
#   'bleach': False,
#   'yawn': False,
#   'chrichton': False,
#   'vegetables': False,
#   'chisolm': False,
#   'slobbered': False,
#   'languid': False,
#   'shoulda': False,
#   'performace': False,
#   'loom': False,
#   'panorama': False,
#   'beckinsale': False,
#   'undercuts': False,
#   'moran': False,
#   'spiritualistic': False,
#   'picket': False,
#   'inspection': False,
#   'terrestrials': False,
#   'immersing': False,
#   'rift': False,
#   'turned': False,
#   'mop': False,
#   'romance': False,
#   'gremlins': False,
#   'merest': False,
#   'snowmen': False,
#   'gerard': False,
#   'tingling': False,
#   'liao': False,
#   'championship': False,
#   'muddy': False,
#   'perky': False,
#   'gangly': False,
#   'algar': False,
#   'consists': False,
#   'sorrier': False,
#   'sexiest': False,
#   'gems': False,
#   'calahan': False,
#   'grooving': False,
#   'haywire': False,
#   'desensitization': False,
#   'milestone': False,
#   'charcoal': False,
#   'stream': False,
#   'zippy': False,
#   'register': False,
#   'amor': False,
#   'sanjay': False,
#   'chabat': False,
#   'fantasizes': False,
#   'leboswki': False,
#   'copter': False,
#   'musn': False,
#   'quivering': False,
#   'robocop': False,
#   'visitors': False,
#   'governor': False,
#   'sally': False,
#   'ups': False,
#   'bodyguard': False,
#   'peasants': False,
#   'foyle': False,
#   'viceroy': False,
#   'brake': False,
#   'toppled': False,
#   'enhance': False,
#   'campell': False,
#   'properly': False,
#   'sensibility': False,
#   'precepts': False,
#   'giggle': False,
#   'pedicure': False,
#   'disorders': False,
#   'bookseller': False,
#   'endemic': False,
#   'bummer': False,
#   'passionless': False,
#   'retention': False,
#   'swoops': False,
#   'interpreter': False,
#   'stuggles': False,
#   '_unbreakable_': False,
#   'palms': False,
#   'lend': False,
#   'renounces': False,
#   'erosion': False,
#   'lankier': False,
#   'interred': False,
#   'worse': False,
#   'candidates': False,
#   'facehugger': False,
#   'robot': False,
#   'examiner': False,
#   'pushed': False,
#   'whacked': False,
#   'jumanji': False,
#   'some': True,
#   'smooch': False,
#   'incapable': False,
#   'rocket': False,
#   'mussolini': False,
#   'sate': False,
#   'undependable': False,
#   'mcjob': False,
#   'ladders': False,
#   'riff': False,
#   'singer': False,
#   'alexi': False,
#   'murray': False,
#   'juni': False,
#   'cuts': False,
#   'blurry': False,
#   'float': False,
#   'elmaloglou': False,
#   'pulsating': False,
#   'aghast': False,
#   'foils': False,
#   'spinoff': False,
#   'cogliostro': False,
#   'cored': False,
#   'animations': False,
#   'elses': False,
#   'airplanes': False,
#   'investigation': False,
#   'wc': False,
#   'skates': False,
#   'ranging': False,
#   'scolex': False,
#   'meteorite': False,
#   'repulsed': False,
#   'tossed': False,
#   'prevention': False,
#   'forsaken': False,
#   'ascend': False,
#   'roughneck': False,
#   'saints': False,
#   'exploiting': False,
#   'invoking': False,
#   'froth': False,
#   'bootsie': False,
#   'niflheim': False,
#   'haze': False,
#   'caberat': False,
#   'snaps': False,
#   'wearing': False,
#   'labeling': False,
#   'phoebe': False,
#   'passable': False,
#   'eisley': False,
#   'treaty': False,
#   'excruciating': False,
#   'igor': False,
#   'organism': False,
#   'sidewalks': False,
#   'fluent': False,
#   'spacey': False,
#   'schitck': False,
#   'chocolat': False,
#   'tainted': False,
#   'pithy': False,
#   'bag': False,
#   'establish': False,
#   'slurs': False,
#   'purchasing': False,
#   'soothingly': False,
#   'paige': False,
#   'presenter': False,
#   'merton': False,
#   'uncritical': False,
#   'malko': False,
#   'need': False,
#   'preforming': False,
#   'delaney': False,
#   'whitehouse': False,
#   'freezing': False,
#   'conceivable': False,
#   'catches': False,
#   'polygram': False,
#   'testosterone': False,
#   'ime': False,
#   'smarts': False,
#   'contrary': False,
#   'wilhelm': False,
#   'start': False,
#   'greenhouse': False,
#   'tentatively': False,
#   'bracken': False,
#   'blaring': False,
#   'richelieu': False,
#   'shang': False,
#   'kicky': False,
#   'stepson': False,
#   'temple': False,
#   'dunois': False,
#   'girls': True,
#   'motivational': False,
#   'rekall': False,
#   'raps': False,
#   'weslely': False,
#   'christina': False,
#   'separating': False,
#   'distilled': False,
#   'eyesight': False,
#   'crazymadinlove': False,
#   'peaceful': False,
#   'zsigmond': False,
#   '_': False,
#   'droll': False,
#   'harriett': False,
#   'aahs': False,
#   'tak': False,
#   'spectaculars': False,
#   'nihilism': False,
#   'splendor': False,
#   'overdrive': False,
#   'sharpster': False,
#   'friedkin': False,
#   'profanities': False,
#   '1554': False,
#   'ffing': False,
#   'shrieking': False,
#   'unrighteous': False,
#   'tasteless': False,
#   'ramones': False,
#   'pagans': False,
#   'gay': False,
#   'zuehlke': False,
#   'covetous': False,
#   'endangered': False,
#   'misuses': False,
#   'granger': False,
#   'improvised': False,
#   'performs': False,
#   'receiveth': False,
#   'combating': False,
#   'sultry': False,
#   'present': False,
#   'prodigy': False,
#   'decapitations': False,
#   'dickinson': False,
#   'senseless': False,
#   'regurgitating': False,
#   'vigau': False,
#   'ostensible': False,
#   'manhunt': False,
#   'flasher': False,
#   'flogging': False,
#   'mostly': False,
#   '_poltergeist_': False,
#   'sideline': False,
#   'contacted': False,
#   'justifies': False,
#   'messiah': False,
#   'petersson': False,
#   'mercer': False,
#   'harmony': False,
#   'confronting': False,
#   'nbc': False,
#   'sweetness': False,
#   'comments': False,
#   'awwwww': False,
#   'disowned': False,
#   'diplomats': False,
#   'austin': False,
#   'describing': False,
#   'edelman': False,
#   'bologna': False,
#   'cultist': False,
#   'graver': False,
#   'romanov': False,
#   'breakout': False,
#   'brazilian': False,
#   'perkiness': False,
#   'accuser': False,
#   'worthwhile': False,
#   'blawp': False,
#   'headless': False,
#   'celebration': False,
#   'participate': False,
#   'sisterhood': False,
#   'heap': False,
#   'sheryl': False,
#   'stressing': False,
#   'offends': False,
#   'hyperbolic': False,
#   'dedicated': False,
#   'bee': False,
#   'clanking': False,
#   'shreck': False,
#   'indiscernable': False,
#   'warchus': False,
#   'agitated': False,
#   'teenth': False,
#   'revivals': False,
#   'schell': False,
#   'manslaughterer': False,
#   'mired': False,
#   'excrucitating': False,
#   'reworks': False,
#   'blankets': False,
#   'tributes': False,
#   'artemus': False,
#   'frontman': False,
#   'petrie': False,
#   'influences': False,
#   'dust': False,
#   'amelie': False,
#   'prigge': False,
#   '126': False,
#   'gayness': False,
#   'battered': False,
#   'iliff': False,
#   'largeur': False,
#   'padawan': False,
#   'peen': False,
#   'wwii': False,
#   'backdraft': False,
#   'conspicuous': False,
#   'historian': False,
#   'contractual': False,
#   'indignantly': False,
#   'learn': False,
#   'ginty': False,
#   'finnegan': False,
#   'hitchhikers': False,
#   'lounging': False,
#   'gussied': False,
#   'dorado': False,
#   'stavro': False,
#   'marc': False,
#   'twiddling': False,
#   'cigars': False,
#   'professionally': False,
#   'reconnassaince': False,
#   'dress': False,
#   'interpreting': False,
#   'professorship': False,
#   'council': False,
#   'streetwalker': False,
#   'tolkin': False,
#   'rivera': False,
#   'prosperous': False,
#   'buton': False,
#   'estimate': False,
#   'periphery': False,
#   'reconciliation': False,
#   'intermingling': False,
#   'grime': False,
#   'ticoton': False,
#   'elitist': False,
#   'terrorist': False,
#   'nass': False,
#   'generations': False,
#   'globes': False,
#   'redheaded': False,
#   'misusing': False,
#   'chicago': False,
#   'expose': False,
#   'requested': False,
#   'embarrassingly': False,
#   'grossness': False,
#   ...},
#  'neg')

# %%
# we can split the featuresets into training and testing datasets using sklearn
from sklearn import model_selection

# We can use sklearn algorithms in NLTK
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import SVC

# define a seed for reproducibility
seed = 1

# split the data into training and testing datasets
training, testing = model_selection.train_test_split(featuresets, test_size = 0.25, random_state=seed)

model = SklearnClassifier(SVC(kernel = 'linear'))

# train the model on the training data
model.train(training)

# and test on the testing dataset!
accuracy = nltk.classify.accuracy(model, testing)*100
print("SVC Accuracy: {}".format(accuracy))
# Out:
# SVC Accuracy: 70.0
