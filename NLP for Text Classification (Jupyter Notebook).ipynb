# %% [markdown]
# ## Natural Language Processing for Text Classification with NLTK and Scikit-learn
#
#
#
# In the project, Getting Started With Natural Language Processing in Python, we learned the basics of tokenizing, part-of-speech tagging, stemming, chunking, and named entity recognition; furthermore, we dove into machine learning and text classification using a simple support vector classifier and a dataset of positive and negative movie reviews.
#
# In this tutorial, we will expand on this foundation and explore different ways to improve our text classification results. We will cover and use:
#
#
# * Regular Expressions
# * Feature Engineering
# * Multiple scikit-learn Classifiers
# * Ensemble Methods
#
# ### 1. Import Necessary Libraries
#
# To ensure the necessary libraries are installed correctly and up-to-date, print the version numbers for each library.  This will also improve the reproducibility of our project.

# %%
import sys
import nltk
import sklearn
import pandas
import numpy

print('Python: {}'.format(sys.version))
print('NLTK: {}'.format(nltk.__version__))
print('Scikit-learn: {}'.format(sklearn.__version__))
print('Pandas: {}'.format(pandas.__version__))
print('Numpy: {}'.format(numpy.__version__))
# Out:
# Python: 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# NLTK: 3.4.4
# Scikit-learn: 0.20.2
# Pandas: 0.24.2
# Numpy: 1.16.3

# %% [markdown]
# ### 2. Load the Dataset
#
# Now that we have ensured that our libraries are installed correctly, let's load the data set as a Pandas DataFrame. Furthermore, let's extract some useful information such as the column information and class distributions.
#
# The data set we will be using comes from the UCI Machine Learning Repository.  It contains over 5000 SMS labeled messages that have been collected for mobile phone spam research. It can be downloaded from the following URL:
#
# https://archive.ics.uci.edu/ml/datasets/sms+spam+collection

# %%
import pandas as pd
import numpy as np

# load the dataset of SMS messages
df = pd.read_table('/mnt/d/6- Books/16085188 (1)/Text Classification/smsspamcollection/SMSSPamCollection', header=None, encoding='utf-8')
# Out:
# /home/yamshee/anaconda3/envs/RASABOT/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
# print useful information about the dataset
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
# 0    5572 non-null object
# 1    5572 non-null object
# dtypes: object(2)
# memory usage: 87.1+ KB
# None
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# check class distribution
classes = df[0]
print(classes.value_counts())
# Out:
# ham     4825
# spam     747
# Name: 0, dtype: int64

# %% [markdown]
# ### 2. Preprocess the Data
#
# Preprocessing the data is an essential step in natural language process. In the following cells, we will convert our class labels to binary values using the LabelEncoder from sklearn, replace email addresses, URLs, phone numbers, and other symbols by using regular expressions, remove stop words, and extract word stems.

# %%
from sklearn.preprocessing import LabelEncoder

# convert class labels to binary values, 0 = ham and 1 = spam
encoder = LabelEncoder()
Y = encoder.fit_transform(classes)

print(Y[:10])
# Out:
# [0 0 1 0 0 1 0 0 1 1]

# %%
df.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# store the SMS message data
text_messages = df[1]
print(text_messages[:10])
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# 5    FreeMsg Hey there darling it's been 3 week's n...
# 6    Even my brother is not like to speak with me. ...
# 7    As per your request 'Melle Melle (Oru Minnamin...
# 8    WINNER!! As a valued network customer you have...
# 9    Had your mobile 11 months or more? U R entitle...
# Name: 1, dtype: object

# %% [markdown]
# #### 2.1 Regular Expressions
#
# Some common regular expression metacharacters - copied from wikipedia
#
# **^**     Matches the starting position within the string. In line-based tools, it matches the starting position of any line.
#
# **.**     Matches any single character (many applications exclude newlines, and exactly which characters are considered newlines is flavor-, character-encoding-, and platform-specific, but it is safe to assume that the line feed character is included). Within POSIX bracket expressions, the dot character matches a literal dot. For example, a.c matches "abc", etc., but [a.c] matches only "a", ".", or "c".
#
# **[ ]**    A bracket expression. Matches a single character that is contained within the brackets. For example, [abc] matches "a", "b", or "c". [a-z] specifies a range which matches any lowercase letter from "a" to "z". These forms can be mixed: [abcx-z] matches "a", "b", "c", "x", "y", or "z", as does [a-cx-z].
# The - character is treated as a literal character if it is the last or the first (after the ^, if present) character within the brackets: [abc-], [-abc]. Note that backslash escapes are not allowed. The ] character can be included in a bracket expression if it is the first (after the ^) character: []abc].
#
# **[^ ]**   Matches a single character that is not contained within the brackets. For example, [^abc] matches any character other than "a", "b", or "c". [^a-z] matches any single character that is not a lowercase letter from "a" to "z". Likewise, literal characters and ranges can be mixed.
#
# **$**      Matches the ending position of the string or the position just before a string-ending newline. In line-based tools, it matches the ending position of any line.
#
# **( )**    Defines a marked subexpression. The string matched within the parentheses can be recalled later (see the next entry, \n). A marked subexpression is also called a block or capturing group. BRE mode requires \( \).
#
# **\n**     Matches what the nth marked subexpression matched, where n is a digit from 1 to 9. This construct is vaguely defined in the POSIX.2 standard. Some tools allow referencing more than nine capturing groups.
#
# **\***     Matches the preceding element zero or more times. For example, ab*c matches "ac", "abc", "abbbc", etc. [xyz]* matches "", "x", "y", "z", "zx", "zyx", "xyzzy", and so on. (ab)* matches "", "ab", "abab", "ababab", and so on.
#
# **{m,n}**  Matches the preceding element at least m and not more than n times. For example, a{3,5} matches only "aaa", "aaaa", and "aaaaa". This is not found in a few older instances of regexes. BRE mode requires \{m,n\}.

# %%
# use regular expressions to replace email addresses, URLs, phone numbers, other numbers

# Replace email addresses with 'email'
processed = text_messages.str.replace(r'^.+@[^\.].*\.[a-z]{2,}$',
                                 'emailaddress')

# Replace URLs with 'webaddress'
processed = processed.str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$',
                                  'webaddress')

# Replace money symbols with 'moneysymb' (£ can by typed with ALT key + 156)
processed = processed.str.replace(r'£|\$', 'moneysymb')
    
# Replace 10 digit phone numbers (formats include paranthesis, spaces, no spaces, dashes) with 'phonenumber'
processed = processed.str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',
                                  'phonenumbr')
    
# Replace numbers with 'numbr'
processed = processed.str.replace(r'\d+(\.\d+)?', 'numbr')

# %%
# Remove punctuation
processed = processed.str.replace(r'[^\w\d\s]', ' ')

# Replace whitespace between terms with a single space
processed = processed.str.replace(r'\s+', ' ')

# Remove leading and trailing whitespace
processed = processed.str.replace(r'^\s+|\s+?$', '')

# %%
# change words to lower case - Hello, HELLO, hello are all the same word
processed = processed.str.lower()
print(processed)
# Out:
# 0       go until jurong point crazy available only in ...
# 1                                 ok lar joking wif u oni
# 2       free entry in numbr a wkly comp to win fa cup ...
# 3             u dun say so early hor u c already then say
# 4       nah i don t think he goes to usf he lives arou...
# 5       freemsg hey there darling it s been numbr week...
# 6       even my brother is not like to speak with me t...
# 7       as per your request melle melle oru minnaminun...
# 8       winner as a valued network customer you have b...
# 9       had your mobile numbr months or more u r entit...
# 10      i m gonna be home soon and i don t want to tal...
# 11      six chances to win cash from numbr to numbr nu...
# 12      urgent you have won a numbr week free membersh...
# 13      i ve been searching for the right words to tha...
# 14                      i have a date on sunday with will
# 15      xxxmobilemovieclub to use your credit click th...
# 16                                 oh k i m watching here
# 17      eh u remember how numbr spell his name yes i d...
# 18      fine if that s the way u feel that s the way i...
# 19      england v macedonia dont miss the goals team n...
# 20               is that seriously how you spell his name
# 21      i m going to try for numbr months ha ha only j...
# 22         so ü pay first lar then when is da stock comin
# 23      aft i finish my lunch then i go str down lor a...
# 24      ffffffffff alright no way i can meet up with y...
# 25      just forced myself to eat a slice i m really n...
# 26                          lol your always so convincing
# 27      did you catch the bus are you frying an egg di...
# 28      i m back amp we re packing the car now i ll le...
# 29      ahhh work i vaguely remember that what does it...
#                               ...
# 5542             armand says get your ass over to epsilon
# 5543                u still havent got urself a jacket ah
# 5544    i m taking derek amp taylor to walmart if i m ...
# 5545        hi its in durban are you still on this number
# 5546             ic there are a lotta childporn cars then
# 5547    had your contract mobile numbr mnths latest mo...
# 5548                     no i was trying it all weekend v
# 5549    you know wot people wear t shirts jumpers hat ...
# 5550            cool what time you think you can get here
# 5551    wen did you get so spiritual and deep that s g...
# 5552    have a safe trip to nigeria wish you happiness...
# 5553                           hahaha use your brain dear
# 5554    well keep in mind i ve only got enough gas for...
# 5555    yeh indians was nice tho it did kane me off a ...
# 5556    yes i have so that s why u texted pshew missin...
# 5557    no i meant the calculation is the same that lt...
# 5558                                sorry i ll call later
# 5559    if you aren t here in the next lt gt hours imm...
# 5560                      anything lor juz both of us lor
# 5561    get me out of this dump heap my mom decided to...
# 5562    ok lor sony ericsson salesman i ask shuhui the...
# 5563                               ard numbr like dat lor
# 5564    why don t you wait til at least wednesday to s...
# 5565                                            huh y lei
# 5566    reminder from onumbr to get numbr pounds free ...
# 5567    this is the numbrnd time we have tried numbr c...
# 5568                  will ü b going to esplanade fr home
# 5569    pity was in mood for that so any other suggest...
# 5570    the guy did some bitching but i acted like i d...
# 5571                            rofl its true to its name
# Name: 1, Length: 5572, dtype: object

# %%
from nltk.corpus import stopwords

# remove stop words from text messages

stop_words = set(stopwords.words('english'))

processed = processed.apply(lambda x: ' '.join(
    term for term in x.split() if term not in stop_words))

# %%
# Remove word stems using a Porter stemmer
ps = nltk.PorterStemmer()

processed = processed.apply(lambda x: ' '.join(
    ps.stem(term) for term in x.split()))

# %% [markdown]
# ### 3. Generating Features
#
# Feature engineering is the process of using domain knowledge of the data to create features for machine learning algorithms. In this project, the words in each text message will be our features.  For this purpose, it will be necessary to tokenize each word.  We will use the 1500 most common words as features.

# %%
from nltk.tokenize import word_tokenize

# create bag-of-words
all_words = []

for message in processed:
    words = word_tokenize(message)
    for w in words:
        all_words.append(w)
        
all_words = nltk.FreqDist(all_words)

# %%
# print the total number of words and the 15 most common words
print('Number of words: {}'.format(len(all_words)))
print('Most common words: {}'.format(all_words.most_common(15)))
# Out:
# Number of words: 6530
# Most common words: [('numbr', 2648), ('u', 1207), ('call', 674), ('go', 456), ('get', 451), ('ur', 391), ('gt', 318), ('lt', 316), ('come', 304), ('moneysymbnumbr', 303), ('ok', 293), ('free', 284), ('day', 276), ('know', 275), ('love', 266)]

# %%
# use the 1500 most common words as features
word_features = list(all_words.keys())[:1500]
word_features
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazi',
#  'avail',
#  'bugi',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amor',
#  'wat',
#  'ok',
#  'lar',
#  'joke',
#  'wif',
#  'u',
#  'oni',
#  'free',
#  'entri',
#  'numbr',
#  'wkli',
#  'comp',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkt',
#  'numbrst',
#  'may',
#  'text',
#  'receiv',
#  'question',
#  'std',
#  'txt',
#  'rate',
#  'c',
#  'appli',
#  'numbrovernumbr',
#  'dun',
#  'say',
#  'earli',
#  'hor',
#  'alreadi',
#  'nah',
#  'think',
#  'goe',
#  'usf',
#  'live',
#  'around',
#  'though',
#  'freemsg',
#  'hey',
#  'darl',
#  'week',
#  'word',
#  'back',
#  'like',
#  'fun',
#  'still',
#  'tb',
#  'xxx',
#  'chg',
#  'send',
#  'moneysymbnumbr',
#  'rcv',
#  'even',
#  'brother',
#  'speak',
#  'treat',
#  'aid',
#  'patent',
#  'per',
#  'request',
#  'mell',
#  'oru',
#  'minnaminungint',
#  'nurungu',
#  'vettam',
#  'set',
#  'callertun',
#  'caller',
#  'press',
#  'copi',
#  'friend',
#  'winner',
#  'valu',
#  'network',
#  'custom',
#  'select',
#  'receivea',
#  'prize',
#  'reward',
#  'claim',
#  'call',
#  'code',
#  'klnumbr',
#  'valid',
#  'hour',
#  'mobil',
#  'month',
#  'r',
#  'entitl',
#  'updat',
#  'latest',
#  'colour',
#  'camera',
#  'co',
#  'gon',
#  'na',
#  'home',
#  'soon',
#  'want',
#  'talk',
#  'stuff',
#  'anymor',
#  'tonight',
#  'k',
#  'cri',
#  'enough',
#  'today',
#  'six',
#  'chanc',
#  'cash',
#  'pound',
#  'cshnumbr',
#  'cost',
#  'numbrp',
#  'day',
#  'numbrday',
#  'tsandc',
#  'repli',
#  'hl',
#  'info',
#  'urgent',
#  'membership',
#  'jackpot',
#  'www',
#  'dbuk',
#  'net',
#  'lccltd',
#  'pobox',
#  'numbrldnwnumbranumbrrwnumbr',
#  'search',
#  'right',
#  'thank',
#  'breather',
#  'promi',
#  'wont',
#  'take',
#  'help',
#  'grant',
#  'fulfil',
#  'wonder',
#  'bless',
#  'time',
#  'date',
#  'sunday',
#  'xxxmobilemovieclub',
#  'use',
#  'credit',
#  'click',
#  'wap',
#  'link',
#  'next',
#  'messag',
#  'http',
#  'com',
#  'qjkgighjjgcbl',
#  'oh',
#  'watch',
#  'eh',
#  'rememb',
#  'spell',
#  'name',
#  'ye',
#  'v',
#  'naughti',
#  'make',
#  'wet',
#  'fine',
#  'way',
#  'feel',
#  'gota',
#  'b',
#  'england',
#  'macedonia',
#  'dont',
#  'miss',
#  'goal',
#  'team',
#  'news',
#  'ur',
#  'nation',
#  'eg',
#  'tri',
#  'wale',
#  'scotland',
#  'numbrtxt',
#  'únumbr',
#  'poboxoxnumbrwnumbrwq',
#  'seriou',
#  'ha',
#  'ü',
#  'pay',
#  'first',
#  'da',
#  'stock',
#  'comin',
#  'aft',
#  'finish',
#  'lunch',
#  'str',
#  'lor',
#  'ard',
#  'smth',
#  'ffffffffff',
#  'alright',
#  'meet',
#  'sooner',
#  'forc',
#  'eat',
#  'slice',
#  'realli',
#  'hungri',
#  'tho',
#  'suck',
#  'mark',
#  'get',
#  'worri',
#  'know',
#  'sick',
#  'turn',
#  'pizza',
#  'lol',
#  'alway',
#  'convinc',
#  'catch',
#  'bu',
#  'fri',
#  'egg',
#  'tea',
#  'mom',
#  'left',
#  'dinner',
#  'love',
#  'amp',
#  'pack',
#  'car',
#  'let',
#  'room',
#  'ahhh',
#  'work',
#  'vagu',
#  'wait',
#  'clear',
#  'sure',
#  'sarcast',
#  'x',
#  'us',
#  'yeah',
#  'apologet',
#  'fallen',
#  'actin',
#  'spoilt',
#  'child',
#  'caught',
#  'till',
#  'badli',
#  'cheer',
#  'tell',
#  'anyth',
#  'fear',
#  'faint',
#  'housework',
#  'quick',
#  'cuppa',
#  'subscript',
#  'rington',
#  'uk',
#  'charg',
#  'plea',
#  'confirm',
#  'yup',
#  'look',
#  'msg',
#  'xuhui',
#  'learn',
#  'numbrnd',
#  'lesson',
#  'numbram',
#  'oop',
#  'roommat',
#  'done',
#  'see',
#  'letter',
#  'decid',
#  'hello',
#  'saturday',
#  'tomo',
#  'invit',
#  'pl',
#  'ahead',
#  'watt',
#  'weekend',
#  'abiola',
#  'forget',
#  'need',
#  'crave',
#  'sweet',
#  'arabian',
#  'steed',
#  'mmmmmm',
#  'yummi',
#  'rodger',
#  'burn',
#  'sm',
#  'nokia',
#  'camcord',
#  'deliveri',
#  'tomorrow',
#  'hope',
#  'man',
#  'well',
#  'endow',
#  'lt',
#  'gt',
#  'inch',
#  'hep',
#  'immuni',
#  'nigeria',
#  'fair',
#  'tyler',
#  'could',
#  'mayb',
#  'ask',
#  'bit',
#  'stubborn',
#  'hospit',
#  'kept',
#  'weak',
#  'sucker',
#  'saw',
#  'class',
#  'gram',
#  'usual',
#  'run',
#  'half',
#  'eighth',
#  'smarter',
#  'almost',
#  'whole',
#  'second',
#  'fyi',
#  'ride',
#  'morn',
#  'crash',
#  'place',
#  'wow',
#  'never',
#  'realiz',
#  'embarass',
#  'accomod',
#  'thought',
#  'sinc',
#  'best',
#  'seem',
#  'happi',
#  'cave',
#  'sorri',
#  'give',
#  'offer',
#  'ac',
#  'sptv',
#  'new',
#  'jersey',
#  'devil',
#  'detroit',
#  'red',
#  'wing',
#  'play',
#  'ice',
#  'hockey',
#  'correct',
#  'incorrect',
#  'end',
#  'mallika',
#  'sherawat',
#  'yesterday',
#  'find',
#  'url',
#  'congrat',
#  'year',
#  'special',
#  'cinema',
#  'pass',
#  'suprman',
#  'matrixnumbr',
#  'starwarsnumbr',
#  'etc',
#  'bxnumbr',
#  'ipnumbr',
#  'numbrw',
#  'numbrpm',
#  'later',
#  'reach',
#  'gauti',
#  'sehwag',
#  'odi',
#  'seri',
#  'pick',
#  'burger',
#  'move',
#  'pain',
#  'kill',
#  'good',
#  'girl',
#  'situat',
#  'seeker',
#  'part',
#  'check',
#  'iq',
#  'took',
#  'forev',
#  'come',
#  'doubl',
#  'hair',
#  'dresser',
#  'said',
#  'wun',
#  'cut',
#  'short',
#  'nice',
#  'advi',
#  'follow',
#  'recent',
#  'review',
#  'mob',
#  'award',
#  'bonu',
#  'song',
#  'dedic',
#  'valuabl',
#  'frnd',
#  'rpli',
#  'complimentari',
#  'trip',
#  'eurodisinc',
#  'trav',
#  'aco',
#  'entrynumbr',
#  'di',
#  'morefrmmob',
#  'shracomorsglsuplt',
#  'lsnumbr',
#  'numbraj',
#  'hear',
#  'divorc',
#  'barbi',
#  'ken',
#  'plane',
#  'wah',
#  'lucki',
#  'save',
#  'money',
#  'hee',
#  'hi',
#  'babe',
#  'im',
#  'wan',
#  'someth',
#  'xx',
#  'perform',
#  'machan',
#  'cool',
#  'gentleman',
#  'digniti',
#  'respect',
#  'peopl',
#  'much',
#  'shi',
#  'pa',
#  'oper',
#  'job',
#  'ta',
#  'earn',
#  'ah',
#  'stop',
#  'urgnt',
#  'real',
#  'yo',
#  'ticket',
#  'one',
#  'jacket',
#  'multi',
#  'start',
#  'came',
#  'bed',
#  'coin',
#  'factori',
#  'nitro',
#  'ela',
#  'kano',
#  'il',
#  'download',
#  'wen',
#  'stand',
#  'close',
#  'anoth',
#  'night',
#  'spent',
#  'late',
#  'afternoon',
#  'casualti',
#  'mean',
#  'stuffnumbrmoro',
#  'includ',
#  'sheet',
#  'smile',
#  'pleasur',
#  'troubl',
#  'pour',
#  'rain',
#  'sumnumbr',
#  'hurt',
#  'becoz',
#  'someon',
#  'servic',
#  'repr',
#  'guarant',
#  'havent',
#  'plan',
#  'buy',
#  'lido',
#  'show',
#  'collect',
#  'simpli',
#  'password',
#  'mix',
#  'verifi',
#  'usher',
#  'britney',
#  'fml',
#  'po',
#  'box',
#  'mknumbr',
#  'numbrh',
#  'numbrppw',
#  'telugu',
#  'movi',
#  'abt',
#  'load',
#  'loan',
#  'wk',
#  'hol',
#  'forgot',
#  'hairdress',
#  'appoint',
#  'four',
#  'shower',
#  'beforehand',
#  'cau',
#  'prob',
#  'coff',
#  'anim',
#  'noth',
#  'el',
#  'okay',
#  'price',
#  'long',
#  'legal',
#  'ave',
#  'gone',
#  'numbrth',
#  'drive',
#  'test',
#  'yet',
#  'guess',
#  'gave',
#  'boston',
#  'men',
#  'chang',
#  'locat',
#  'nyc',
#  'cuz',
#  'signin',
#  'page',
#  'umma',
#  'life',
#  'vava',
#  'lot',
#  'dear',
#  'wish',
#  'birthday',
#  'truli',
#  'memor',
#  'aight',
#  'hit',
#  'would',
#  'ip',
#  'address',
#  'consid',
#  'comput',
#  'minecraft',
#  'server',
#  'grumpi',
#  'old',
#  'better',
#  'lie',
#  'busi',
#  'plural',
#  'noun',
#  'research',
#  'thing',
#  'scare',
#  'mah',
#  'loud',
#  'gent',
#  'contact',
#  'last',
#  'draw',
#  'knumbr',
#  'numbrhr',
#  'numbrppm',
#  'wa',
#  'openin',
#  'sentenc',
#  'formal',
#  'anyway',
#  'juz',
#  'tt',
#  'eatin',
#  'puttin',
#  'weight',
#  'haha',
#  'anythin',
#  'happen',
#  'enter',
#  'cabin',
#  'boss',
#  'felt',
#  'askd',
#  'apart',
#  'went',
#  'holiday',
#  'flight',
#  'inc',
#  'min',
#  'goodo',
#  'must',
#  'friday',
#  'potato',
#  'ratio',
#  'tortilla',
#  'hmm',
#  'uncl',
#  'inform',
#  'school',
#  'directli',
#  'food',
#  'privat',
#  'account',
#  'statement',
#  'unredeem',
#  'identifi',
#  'expir',
#  'landlin',
#  'boxnumbrwrnumbrc',
#  'appl',
#  'pair',
#  'malarki',
#  'voda',
#  'number',
#  'match',
#  'quot',
#  'standard',
#  'app',
#  'sao',
#  'mu',
#  'predict',
#  'yetund',
#  'sent',
#  'bother',
#  'involv',
#  'impo',
#  'apolog',
#  'del',
#  'bak',
#  'sum',
#  'lucyxx',
#  'tmorrow',
#  'answer',
#  'sunshin',
#  'quiz',
#  'q',
#  'top',
#  'soni',
#  'dvd',
#  'player',
#  'countri',
#  'algarv',
#  'ansr',
#  'sp',
#  'tyron',
#  'laid',
#  'dog',
#  'direct',
#  'join',
#  'largest',
#  'bt',
#  'txting',
#  'gravel',
#  'nt',
#  'ecnumbra',
#  'emailaddress',
#  'befor',
#  'activ',
#  'chat',
#  'svc',
#  'hardcor',
#  'age',
#  'yr',
#  'lazi',
#  'type',
#  'lect',
#  'pouch',
#  'sir',
#  'mail',
#  'swt',
#  'nver',
#  'tire',
#  'littl',
#  'lovabl',
#  'person',
#  'coz',
#  'somtim',
#  'occupi',
#  'biggest',
#  'heart',
#  'gud',
#  'ninumbr',
#  'open',
#  'ya',
#  'dot',
#  'staff',
#  'randi',
#  'sexi',
#  'femal',
#  'local',
#  'luv',
#  'netcollex',
#  'ltd',
#  'ummma',
#  'begin',
#  'qatar',
#  'pray',
#  'hard',
#  'delet',
#  'sindu',
#  'birla',
#  'soft',
#  'wine',
#  'flow',
#  'thk',
#  'plaza',
#  'typic',
#  'everywh',
#  'dirt',
#  'floor',
#  'window',
#  'shirt',
#  'sometim',
#  'mouth',
#  'dream',
#  'without',
#  'chore',
#  'joy',
#  'tv',
#  'exist',
#  'hail',
#  'mist',
#  'becom',
#  'aaooooright',
#  'leav',
#  'hou',
#  'interview',
#  'boy',
#  'annonc',
#  'arrang',
#  'keep',
#  'safe',
#  'envi',
#  'everyon',
#  'parent',
#  'hand',
#  'excit',
#  'spend',
#  'bootyd',
#  'f',
#  'bangbab',
#  'order',
#  'content',
#  'goto',
#  'bangb',
#  'internet',
#  'menu',
#  'cultur',
#  'modul',
#  'snumbr',
#  'avoid',
#  'missunderstd',
#  'wit',
#  'belov',
#  'escap',
#  'fanci',
#  'bridg',
#  'lager',
#  'complet',
#  'form',
#  'clark',
#  'also',
#  'utter',
#  'wast',
#  'axi',
#  'bank',
#  'hmmm',
#  'hop',
#  'muz',
#  'discuss',
#  'liao',
#  'bloodi',
#  'hell',
#  'cant',
#  'believ',
#  'surnam',
#  'mr',
#  'ill',
#  'clue',
#  'spanish',
#  'bath',
#  'carlo',
#  'mall',
#  'stay',
#  'til',
#  'smoke',
#  'moneysymb',
#  'worth',
#  'doesnt',
#  'log',
#  'spoke',
#  'maneesha',
#  'satisfi',
#  'experi',
#  'toll',
#  'lift',
#  'especi',
#  'approach',
#  'studi',
#  'grnumbr',
#  'trust',
#  'guy',
#  'bye',
#  'handsom',
#  'toward',
#  'mummi',
#  'boytoy',
#  'awesom',
#  'minut',
#  'freephon',
#  'xma',
#  'radio',
#  'ju',
#  'si',
#  'uniqu',
#  'august',
#  'areyouuniqu',
#  'leagu',
#  'touch',
#  'deal',
#  'cour',
#  'howev',
#  'suggest',
#  'abl',
#  'everi',
#  'stool',
#  'settl',
#  'wishin',
#  'mrng',
#  'hav',
#  'stori',
#  'hamster',
#  'dead',
#  'tmr',
#  'orchard',
#  'mrt',
#  'kate',
#  'babyjontet',
#  'found',
#  'enc',
#  'buck',
#  'darlin',
#  'ive',
#  'colleg',
#  'refil',
#  'success',
#  'inr',
#  'decim',
#  'keralacircl',
#  'prepaid',
#  'balanc',
#  'rs',
#  'transact',
#  'id',
#  'kr',
#  'goodmorn',
#  'sleep',
#  'ga',
#  'alter',
#  'dat',
#  'ericsson',
#  'oso',
#  'can',
#  'not',
#  'oredi',
#  'straight',
#  'dogg',
#  'connect',
#  'refund',
#  'bill',
#  'shoot',
#  'big',
#  'readi',
#  'bruv',
#  'break',
#  'semest',
#  'noe',
#  'leh',
#  'sound',
#  'head',
#  'slept',
#  'past',
#  'easi',
#  'sen',
#  'exam',
#  'march',
#  'atm',
#  'regist',
#  'os',
#  'ubandu',
#  'instal',
#  'disk',
#  'import',
#  'file',
#  'system',
#  'repair',
#  'shop',
#  'romant',
#  'nite',
#  'sceneri',
#  'tc',
#  'biz',
#  'numbroptout',
#  'numbrgbp',
#  'mtmsgnumbr',
#  'appreci',
#  'partner',
#  'career',
#  'flyng',
#  'horo',
#  'star',
#  'sign',
#  'g',
#  'ari',
#  'compani',
#  'elama',
#  'mudyadhu',
#  'strict',
#  'teacher',
#  'bcoz',
#  'teach',
#  'conduct',
#  'gandhipuram',
#  'walk',
#  'cross',
#  'road',
#  'side',
#  'street',
#  'rubber',
#  'batteri',
#  'die',
#  'flirt',
#  'sam',
#  'recd',
#  'thirtyeight',
#  'penc',
#  'print',
#  ...]

# %%
# The find_features function will determine which of the 1500 word features are contained in the review
def find_features(message):
    words = word_tokenize(message)
    features = {}
    for word in word_features:
        features[word] = (word in words)

    return features

# Lets see an example!
features = find_features(processed[0])
for key, value in features.items():
    if value == True:
        print (key)
# Out:
# go
# jurong
# point
# crazi
# avail
# bugi
# n
# great
# world
# la
# e
# buffet
# cine
# got
# amor
# wat

# %%
# Now lets do it for all the messages
messages = zip(processed, Y)
messages

# %%
mapped = list(messages)
mapped
# Out:
# [('go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#   0),
#  ('ok lar joke wif u oni', 0),
#  ('free entri numbr wkli comp win fa cup final tkt numbrst may numbr text fa numbr receiv entri question std txt rate c appli numbrovernumbr',
#   1),
#  ('u dun say earli hor u c alreadi say', 0),
#  ('nah think goe usf live around though', 0),
#  ('freemsg hey darl numbr week word back like fun still tb ok xxx std chg send moneysymbnumbr rcv',
#   1),
#  ('even brother like speak treat like aid patent', 0),
#  ('per request mell mell oru minnaminungint nurungu vettam set callertun caller press numbr copi friend callertun',
#   0),
#  ('winner valu network custom select receivea moneysymbnumbr prize reward claim call numbr claim code klnumbr valid numbr hour',
#   1),
#  ('mobil numbr month u r entitl updat latest colour mobil camera free call mobil updat co free numbr',
#   1),
#  ('gonna home soon want talk stuff anymor tonight k cri enough today', 0),
#  ('six chanc win cash numbr numbr numbr pound txt cshnumbr send numbr cost numbrp day numbrday numbr tsandc appli repli hl numbr info',
#   1),
#  ('urgent numbr week free membership moneysymbnumbr numbr prize jackpot txt word claim numbr c www dbuk net lccltd pobox numbrldnwnumbranumbrrwnumbr',
#   1),
#  ('search right word thank breather promi wont take help grant fulfil promi wonder bless time',
#   0),
#  ('date sunday', 0),
#  ('xxxmobilemovieclub use credit click wap link next txt messag click http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#   1),
#  ('oh k watch', 0),
#  ('eh u rememb numbr spell name ye v naughti make v wet', 0),
#  ('fine way u feel way gota b', 0),
#  ('england v macedonia dont miss goal team news txt ur nation team numbr eg england numbr tri wale scotland numbrtxt únumbr poboxoxnumbrwnumbrwq numbr',
#   1),
#  ('seriou spell name', 0),
#  ('go tri numbr month ha ha joke', 0),
#  ('ü pay first lar da stock comin', 0),
#  ('aft finish lunch go str lor ard numbr smth lor u finish ur lunch alreadi',
#   0),
#  ('ffffffffff alright way meet sooner', 0),
#  ('forc eat slice realli hungri tho suck mark get worri know sick turn pizza lol',
#   0),
#  ('lol alway convinc', 0),
#  ('catch bu fri egg make tea eat mom left dinner feel love', 0),
#  ('back amp pack car let know room', 0),
#  ('ahhh work vagu rememb feel like lol', 0),
#  ('wait still clear sure sarcast x want live us', 0),
#  ('yeah got numbr v apologet n fallen actin like spoilt child got caught till numbr go badli cheer',
#   0),
#  ('k tell anyth', 0),
#  ('fear faint housework quick cuppa', 0),
#  ('thank subscript rington uk mobil charg moneysymbnumbr month plea confirm repli ye repli charg',
#   1),
#  ('yup ok go home look time msg ü xuhui go learn numbrnd may lesson numbram',
#   0),
#  ('oop let know roommat done', 0),
#  ('see letter b car', 0),
#  ('anyth lor u decid', 0),
#  ('hello saturday go text see decid anyth tomo tri invit anyth', 0),
#  ('pl go ahead watt want sure great weekend abiola', 0),
#  ('forget tell want need crave love sweet arabian steed mmmmmm yummi', 0),
#  ('numbr rodger burn msg tri call repli sm free nokia mobil free camcord plea call numbr deliveri tomorrow',
#   1),
#  ('see', 0),
#  ('great hope like man well endow lt gt inch', 0),
#  ('call messag miss call', 0),
#  ('get hep b immuni nigeria', 0),
#  ('fair enough anyth go', 0),
#  ('yeah hope tyler could mayb ask around bit', 0),
#  ('u know stubborn even want go hospit kept tell mark weak sucker hospit weak sucker',
#   0),
#  ('think first time saw class', 0),
#  ('gram usual run like lt gt half eighth smarter though get almost whole second gram lt gt',
#   0),
#  ('k fyi x ride earli tomorrow morn crash place tonight', 0),
#  ('wow never realiz embarass accomod thought like sinc best could alway seem happi cave sorri give sorri offer sorri room embarass',
#   0),
#  ('sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv',
#   1),
#  ('know mallika sherawat yesterday find lt url gt', 0),
#  ('congrat numbr year special cinema pass numbr call numbr c suprman v matrixnumbr starwarsnumbr etc numbr free bxnumbr ipnumbr numbrw numbrpm dont miss',
#   1),
#  ('sorri call later meet', 0),
#  ('tell reach', 0),
#  ('ye gauti sehwag odi seri', 0),
#  ('gonna pick moneysymbnumbr burger way home even move pain kill', 0),
#  ('ha ha ha good joke girl situat seeker', 0),
#  ('part check iq', 0),
#  ('sorri roommat took forev ok come', 0),
#  ('ok lar doubl check wif da hair dresser alreadi said wun cut v short said cut look nice',
#   0),
#  ('valu custom plea advi follow recent review mob award moneysymbnumbr bonu prize call numbr',
#   1),
#  ('today song dedic day song u dedic send ur valuabl frnd first rpli', 0),
#  ('urgent ur award complimentari trip eurodisinc trav aco entrynumbr moneysymbnumbr claim txt di numbr numbr numbr moneysymbnumbr morefrmmob shracomorsglsuplt numbr lsnumbr numbraj',
#   1),
#  ('hear new divorc barbi come ken stuff', 1),
#  ('plane give month end', 0),
#  ('wah lucki man save money hee', 0),
#  ('finish class', 0),
#  ('hi babe im home wanna someth xx', 0),
#  ('k k perform', 0),
#  ('u call', 0),
#  ('wait machan call free', 0),
#  ('cool gentleman treat digniti respect', 0),
#  ('like peopl much shi pa', 0),
#  ('oper lt gt', 0),
#  ('still look job much ta earn', 0),
#  ('sorri call later', 0),
#  ('k call ah', 0),
#  ('ok way home hi hi', 0),
#  ('place man', 0),
#  ('yup next stop', 0),
#  ('call later network urgnt sm', 0),
#  ('real u get yo need numbr ticket one jacket done alreadi use multi', 0),
#  ('ye start send request make pain came back back bed doubl coin factori gotta cash nitro',
#   0),
#  ('realli still tonight babe', 0),
#  ('ela kano il download come wen ur free', 0),
#  ('yeah stand close tho catch someth', 0),
#  ('sorri pain ok meet anoth night spent late afternoon casualti mean done stuffnumbrmoro includ time sheet sorri',
#   0),
#  ('smile pleasur smile pain smile troubl pour like rain smile sumnumbr hurt u smile becoz someon still love see u smile',
#   0),
#  ('plea call custom servic repr numbr numbr numbr numbram numbrpm guarant moneysymbnumbr cash moneysymbnumbr prize',
#   1),
#  ('havent plan buy later check alreadi lido got numbr show e afternoon u finish work alreadi',
#   0),
#  ('free rington wait collect simpli text password mix numbr verifi get usher britney fml po box numbr mknumbr numbrh numbrppw numbr',
#   1),
#  ('watch telugu movi wat abt u', 0),
#  ('see finish load loan pay', 0),
#  ('hi wk ok hol ye bit run forgot hairdress appoint four need get home n shower beforehand cau prob u',
#   0),
#  ('see cup coff anim', 0),
#  ('plea text anymor noth el say', 0),
#  ('okay name ur price long legal wen pick u ave x xx', 0),
#  ('still look car buy gone numbrth drive test yet', 0),
#  ('per request mell mell oru minnaminungint nurungu vettam set callertun caller press numbr copi friend callertun',
#   0),
#  ('wow right mean guess gave boston men chang search locat nyc someth chang cuz signin page still say boston',
#   0),
#  ('umma life vava umma love lot dear', 0),
#  ('thank lot wish birthday thank make birthday truli memor', 0),
#  ('aight hit get cash', 0),
#  ('would ip address test consid comput minecraft server', 0),
#  ('know grumpi old peopl mom like better lie alway one play joke', 0),
#  ('dont worri guess busi', 0),
#  ('plural noun research', 0),
#  ('go dinner msg', 0),
#  ('ok wif co like numbr tri new thing scare u dun like mah co u said loud', 0),
#  ('gent tri contact last weekend draw show moneysymbnumbr prize guarant call numbr claim code knumbr valid numbrhr numbrppm',
#   1),
#  ('wa ur openin sentenc formal anyway fine juz tt eatin much n puttin weight haha anythin special happen',
#   0),
#  ('enter cabin pa said happi b day boss felt special askd numbr lunch lunch invit apart went',
#   0),
#  ('winner u special select numbr receiv moneysymbnumbr numbr holiday flight inc speak live oper numbr claim numbrp min numbr',
#   1),
#  ('goodo ye must speak friday egg potato ratio tortilla need', 0),
#  ('hmm uncl inform pay school directli pl buy food', 0),
#  ('privat numbr account statement numbr show numbr unredeem bonu point claim call numbr identifi code numbr expir',
#   1),
#  ('urgent mobil award moneysymbnumbr bonu caller prize numbr numbr numbr final tri contact u call landlin numbr boxnumbrwrnumbrc numbrppm',
#   1),
#  ('new address appl pair malarki', 0),
#  ('today voda number end numbr select receiv moneysymbnumbr award match plea call numbr quot claim code numbr standard rate app',
#   1),
#  ('go sao mu today done numbr', 0),
#  ('ü predict wat time ü finish buy', 0),
#  ('good stuff', 0),
#  ('know yetund sent money yet sent text bother send dont involv anyth impo anyth first place apolog',
#   0),
#  ('room', 0),
#  ('hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#   0),
#  ('k k much cost', 0),
#  ('home', 0),
#  ('dear call tmorrow pl accomod', 0),
#  ('first answer question', 0),
#  ('sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr numbr moneysymbnumbr sp tyron',
#   1),
#  ('want numbr get laid tonight want real dog locat sent direct numbr ur mob join uk largest dog network bt txting gravel numbr nt ecnumbra numbrp msg numbrp',
#   1),
#  ('emailaddress', 0),
#  ('call meet', 0),
#  ('check room befor activ', 0),
#  ('rcv msg chat svc free hardcor servic text go numbr u get noth u must age verifi yr network tri',
#   1),
#  ('got c lazi type forgot ü lect saw pouch like v nice', 0),
#  ('k text way', 0),
#  ('sir wait mail', 0),
#  ('swt thought nver get tire littl thing numbr lovabl person coz somtim littl thing occupi biggest part heart gud ninumbr',
#   0),
#  ('know pl open back', 0),
#  ('ye see ya dot', 0),
#  ('staff name take class us', 0),
#  ('freemsg repli text randi sexi femal live local luv hear u netcollex ltd numbrp per msg repli stop end',
#   1),
#  ('ummma call check life begin qatar pl pray hard', 0),
#  ('k delet contact', 0),
#  ('sindu got job birla soft', 0),
#  ('wine flow never', 0),
#  ('yup thk cine better co need numbr go numbr plaza mah', 0),
#  ('ok ur typic repli', 0),
#  ('per request mell mell oru minnaminungint nurungu vettam set callertun caller press numbr copi friend callertun',
#   0),
#  ('everywh dirt floor window even shirt sometim open mouth come flow dream world without half chore time joy lot tv show see guess like thing must exist like rain hail mist time done becom one',
#   0),
#  ('aaooooright work', 0),
#  ('leav hou', 0),
#  ('hello love get interview today happi good boy think miss', 0),
#  ('custom servic annonc new year deliveri wait plea call numbr arrang deliveri',
#   1),
#  ('winner u special select numbr receiv moneysymbnumbr cash numbr holiday flight inc speak live oper numbr claim numbr',
#   1),
#  ('keep safe need miss alreadi envi everyon see real life', 0),
#  ('new car hou parent new job hand', 0),
#  ('love excit day spend make happi', 0),
#  ('pl stop bootyd numbr f invit friend repli ye numbr numbr see www sm ac u bootyd stop send stop frnd numbr',
#   1),
#  ('bangbab ur order way u receiv servic msg numbr download ur content u goto wap bangb tv ur mobil internet servic menu',
#   1),
#  ('place ur point e cultur modul alreadi', 0),
#  ('urgent tri contact last weekend draw show moneysymbnumbr prize guarant call numbr claim code snumbr valid numbrhr',
#   1),
#  ('hi frnd best way avoid missunderstd wit belov one', 0),
#  ('great escap fanci bridg need lager see tomo', 0),
#  ('ye complet form clark also utter wast', 0),
#  ('sir need axi bank account bank address', 0),
#  ('hmmm thk sure got time hop ard ya go numbr free abt muz call u discuss liao',
#   0),
#  ('time come later', 0),
#  ('bloodi hell cant believ forgot surnam mr ill give u clue spanish begin', 0),
#  ('well gonna finish bath good fine night', 0),
#  ('let know got money carlo make call', 0),
#  ('u still go mall', 0),
#  ('turn friend stay whole show back til lt gt feel free go ahead smoke moneysymb lt gt worth',
#   0),
#  ('text doesnt repli let know log', 0),
#  ('hi spoke maneesha v like know satisfi experi repli toll free ye', 0),
#  ('lift hope offer money need especi end month approach hurt studi anyway grnumbr weekend',
#   0),
#  ('lol u trust', 0),
#  ('ok gentleman treat digniti respect', 0),
#  ('guy close', 0),
#  ('go noth great bye', 0),
#  ('hello handsom find job lazi work toward get back net mummi boytoy miss', 0),
#  ('haha awesom minut', 0),
#  ('plea call custom servic repr freephon numbr numbr numbr numbram numbrpm guarant moneysymbnumbr cash moneysymbnumbr prize',
#   1),
#  ('got xma radio time get', 0),
#  ('ju reach home go bath first si use net tell u finish k', 0),
#  ('uniqu enough find numbrth august www areyouuniqu co uk', 1),
#  ('sorri join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#   0),
#  ('hi final complet cour', 0),
#  ('stop howev suggest stay someon abl give everi stool', 0),
#  ('hope settl new school year wishin grnumbr day', 0),
#  ('gud mrng dear hav nice day', 0),
#  ('u got person stori', 0),
#  ('hamster dead hey tmr meet numbrpm orchard mrt', 0),
#  ('hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx', 0),
#  ('found enc lt gt', 0),
#  ('sent lt gt buck', 0),
#  ('hello darlin ive finish colleg txt u finish u love kate xxx', 0),
#  ('account refil success inr lt decim gt keralacircl prepaid account balanc rs lt decim gt transact id kr lt gt',
#   0),
#  ('goodmorn sleep ga', 0),
#  ('u call alter numbr ok', 0),
#  ('ü say like dat dun buy ericsson oso cannot oredi lar', 0),
#  ('enter cabin pa said happi b day boss felt special askd numbr lunch lunch invit apart went',
#   0),
#  ('aight yo dat straight dogg', 0),
#  ('plea give us connect today lt decim gt refund bill', 0),
#  ('shoot big load get readi', 0),
#  ('bruv hope great break reward semest', 0),
#  ('home alway chat', 0),
#  ('k k good studi well', 0),
#  ('yup ü noe leh', 0),
#  ('sound great home', 0),
#  ('final match head toward draw predict', 0),
#  ('tire slept well past night', 0),
#  ('easi ah sen got select mean good', 0),
#  ('take exam march numbr', 0),
#  ('yeah think use gt atm regist sure anyway help let know sure readi', 0),
#  ('ok prob take ur time', 0),
#  ('os call ubandu run without instal hard disk use os copi import file system give repair shop',
#   0),
#  ('sorri call later', 0),
#  ('u say leh cour noth happen lar say v romant ju bit lor thk e nite sceneri nice leh',
#   0),
#  ('numbr new mobil numbr must go txt nokia numbr collect today moneysymbnumbr www numbr tc biz numbroptout numbrgbp mtmsgnumbr',
#   1),
#  ('would realli appreci call need someon talk', 0),
#  ('u meet ur dream partner soon ur career numbr flyng start numbr find free txt horo follow ur star sign e g horo ari',
#   1),
#  ('hey compani elama po mudyadhu', 0),
#  ('life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#   0),
#  ('dear good morn', 0),
#  ('get gandhipuram walk cross cut road right side lt gt street road turn first right',
#   0),
#  ('dear go rubber place', 0),
#  ('sorri batteri die yeah', 0),
#  ('ye tv alway avail work place', 0),
#  ('text meet someon sexi today u find date even flirt u join numbr numbrp repli name age eg sam numbr numbr msg recd thirtyeight penc',
#   1),
#  ('print oh lt gt come upstair', 0),
#  ('ill littl closer like bu stop street', 0),
#  ('wil reach', 0),
#  ('new theori argument win situat lose person dont argu ur friend kick amp say alway correct',
#   0),
#  ('u numbr secret admir look numbr make contact u find r reveal think ur special call numbr',
#   1),
#  ('tomarrow final hear laptop case cant', 0),
#  ('pleassssssseeee tel v avent done sportsx', 0),
#  ('okay shine meant sign sound better', 0),
#  ('although told u dat baig face watch realli like e watch u gave co fr u thanx numbr everyth dat u done today touch',
#   0),
#  ('u rememb old commerci', 0),
#  ('late said websit dont slipper', 0),
#  ('ask call ok', 0),
#  ('kalli wont bat numbrnd inning', 0),
#  ('didnt work oh ok goodnight fix readi time wake dearli miss good night sleep',
#   0),
#  ('congratul ur award numbr cd voucher numbrgift guarant free entri numbr numbr wkli draw txt music numbr tnc www ldew comnumbrwinnumbrppmxnumbragenumbr',
#   1),
#  ('ranjith cal drpd deeraj deepak numbrmin hold', 0),
#  ('wen ur lovabl bcum angri wid u dnt take seriou coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#   0),
#  ('', 0),
#  ('numbrday also ship compani take numbrwk way usp take week get lag may bribe nipost get stuff',
#   0),
#  ('back lemm know readi', 0),
#  ('necessarili expect done get back though headin', 0),
#  ('mmm yummi babe nice jolt suzi', 0),
#  ('lover need', 0),
#  ('tri contact repli offer video handset numbr anytim network min unlimit text camcord repli call numbr',
#   1),
#  ('park next mini come today think', 0),
#  ('yup', 0),
#  ('anyway go shop co si done yet dun disturb u liao', 0),
#  ('luton numbr ring ur around h', 0),
#  ('hey realli horni want chat see nake text hot numbr text charg numbrpm unsubscrib text stop numbr',
#   1),
#  ('dint come us', 0),
#  ('wana plan trip sometm', 0),
#  ('sure yet still tri get hold', 0),
#  ('ur rington servic chang numbr free credit go clubnumbrmobil com choo content stop txt club stop numbr numbrp wk clubnumbr po boxnumbr mknumbr numbrwt',
#   1),
#  ('evo download flash jealou', 0),
#  ('rington club get uk singl chart mobil week choo top qualiti rington messag free charg',
#   1),
#  ('come mu sort narcot situat', 0),
#  ('night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay',
#   0),
#  ('hmv bonu special numbr pound genuin hmv voucher answer numbr easi question play send hmv numbr info www numbrperc real com',
#   1),
#  ('usf guess might well take numbr car', 0),
#  ('object bf come', 0),
#  ('thanx', 0),
#  ('tell rob mack gf theater', 0),
#  ('awesom see bit', 0),
#  ('sent type food like', 0),
#  ('done hand celebr full swing yet', 0),
#  ('got call tool', 0),
#  ('wen u miss someon person definit special u person special miss keep touch gdeve',
#   0),
#  ('ok ask money far', 0),
#  ('oki', 0),
#  ('yeah think usual guy still pass last night get ahold anybodi let know throw',
#   0),
#  ('k might come tonight class let earli', 0),
#  ('ok', 0),
#  ('hi babi im cruisin girl friend r u numbr give call hour home alright fone fone love jenni xxx',
#   0),
#  ('life mean lot love life love peopl life world call friend call world ge',
#   0),
#  ('dear shall mail tonit busi street shall updat tonit thing look ok varunnathu edukkukay raksha ollu good one real sen',
#   0),
#  ('hey told name gautham ah', 0),
#  ('haf u found feel stupid da v cam work', 0),
#  ('oop numbr got bit', 0),
#  ('much buzi', 0),
#  ('accid delet messag resend plea', 0),
#  ('mobil custom may claim free camera phone upgrad pay go sim card loyalti call numbr numbr numbr offer end numbrthfeb c appli',
#   1),
#  ('unless situat go gurl would appropri', 0),
#  ('hurt tea make cri end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#   0),
#  ('cant pick phone right pl send messag', 0),
#  ('need coff run tomo believ time week alreadi', 0),
#  ('awesom rememb last time got somebodi high first time diesel v', 0),
#  ('shit realli shock scari cant imagin second def night u think somewh could crash night save taxi',
#   0),
#  ('oh way food fridg want go meal tonight', 0),
#  ('womdar actor', 0),
#  ('sm ac blind date numbru roddsnumbr numbr aberdeen unit kingdom check http img sm ac w icmbnumbrcktznumbrrnumbr numbr blind date send hide',
#   1),
#  ('yup remb think book', 0),
#  ('jo ask u wana meet', 0),
#  ('lol ye friendship hang thread cau u buy stuff', 0),
#  ('themob check newest select content game tone gossip babe sport keep mobil fit funki text wap numbr',
#   1),
#  ('garag key bookshelf', 0),
#  ('today accept day u accept brother sister lover dearnumbr bestnumbr closnumbr lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#   0),
#  ('think ur smart win moneysymbnumbr week weekli quiz text play numbr cs winnersclub po box numbr mnumbr numbruz numbr gbpnumbr week',
#   1),
#  ('say give call friend got money definit buy end week', 0),
#  ('hi way u numbrday normal way real ur uniqu hope know u numbr rest mylif hope u find wot lost',
#   0),
#  ('made day great day', 0),
#  ('k k advanc happi pongal', 0),
#  ('hmmm guess go numbr kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#   0),
#  ('realli dude friend afraid', 0),
#  ('decemb mobil numbrmth entitl updat latest colour camera mobil free call mobil updat co free numbr',
#   1),
#  ('coff cake guess', 0),
#  ('merri christma babe love ya kiss', 0),
#  ('hey dont go watch x men lunch haha', 0),
#  ('cud u tell ppl im gona b bit lnumbr co numbr buse hav gon past co full im still waitin numbr numbr pete x',
#   0),
#  ('would great guild could meet bristol road somewh get touch weekend plan take flight good week',
#   0),
#  ('problem', 0),
#  ('call messag miss call', 0),
#  ('hi da today class', 0),
#  ('say good sign well know track record read women', 0),
#  ('cool text park', 0),
#  ('read text sent meant joke read light', 0),
#  ('k k apo k good movi', 0),
#  ('mayb could get book tomo return immedi someth', 0),
#  ('call germani numbr penc per minut call fix line via access number numbr numbr numbr numbr prepay direct access',
#   1),
#  ('chanc might evapor soon violat privaci steal phone number employ paperwork cool plea contact report supervisor',
#   0),
#  ('valentin day special win moneysymbnumbr quiz take partner trip lifetim send go numbr numbrp msg rcvd custcar numbr',
#   1),
#  ('ta daaaaa home babe still', 0),
#  ('cool come havent wine dine', 0),
#  ('sleep surf', 0),
#  ('sorri call later', 0),
#  ('u call right call hand phone', 0),
#  ('ok great thanx lot', 0),
#  ('take post come must numbr text happi read one wiv hello carolin end favourit bless',
#   0),
#  ('u hide stranger', 0),
#  ('interest like', 0),
#  ('sister clear two round birla soft yesterday', 0),
#  ('gudnit tc practic go', 0),
#  ('di yiju ju saw ur mail case huim havent sent u num di num', 0),
#  ('one small prestig problem', 0),
#  ('fanci shag interest sextextuk com txt xxuk suzi numbr txt cost numbr per msg tnc websit x',
#   1),
#  ('check realli miss see jeremiah great month', 0),
#  ('nah help never iphon', 0),
#  ('car hour half go apeshit', 0),
#  ('today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault basic good',
#   0),
#  ('yo guy ever figur much need alcohol jay tri figur much safe spend weed', 0),
#  ('lt gt ish minut numbr minut ago wtf', 0),
#  ('thank call forgot say happi onam sirji fine rememb met insur person meet qatar insha allah rakhesh ex tata aig join tissco tayseer',
#   0),
#  ('congratul ur award numbr cd voucher numbrgift guarant free entri numbr numbr wkli draw txt music numbr tnc www ldew comnumbrwinnumbrppmxnumbragenumbr',
#   1),
#  ('ur cash balanc current numbr pound maxim ur cash send cash numbr numbrp msg cc numbr hg suitenumbr numbrland row wnumbrjnumbrhl',
#   1),
#  ('actor work work even sleep late sinc unemploy moment alway sleep late unemploy everi day saturday',
#   0),
#  ('hello got st andrew boy long way cold keep post', 0),
#  ('ha ha cool cool chikku chikku db', 0),
#  ('oh ok prob', 0),
#  ('check audrey statu right', 0),
#  ('busi tri finish new year look forward final meet', 0),
#  ('good afternoon sunshin dawn day refresh happi aliv breath air smile think love alway',
#   0),
#  ('well know z take care worri', 0),
#  ('update_now xma offer latest motorola sonyericsson nokia free bluetooth doubl min numbr txt orang call mobileupdnumbr numbr callnumbroptout fnumbrq',
#   1),
#  ('discount code rpnumbr stop messag repli stop www regalportfolio co uk custom servic numbr',
#   1),
#  ('wat uniform get', 0),
#  ('cool text readi', 0),
#  ('hello boytoy geeee miss alreadi woke wish bed cuddl love', 0),
#  ('spoil bed well', 0),
#  ('go bath msg next lt gt min', 0),
#  ('cant keep talk peopl sure pay agr price pl tell want realli buy much pay',
#   0),
#  ('thank rington order refer tnumbr charg gbp numbr per week unsubscrib anytim call custom servic numbr',
#   1),
#  ('say happen', 0),
#  ('could seen recogni face', 0),
#  ('well lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#   0),
#  ('keep payasam rinu bring', 0),
#  ('taught ranjith sir call sm like becau verifi project prabu told today pa dont mistak',
#   0),
#  ('guess worri must know way bodi repair quit sure worri take slow first test guid ovul relax noth said reason worri keep followin',
#   0),
#  ('yeah sure give coupl minut track wallet', 0),
#  ('hey leav big deal take care', 0),
#  ('hey late ah meet numbr', 0),
#  ('doubl min txt numbr numbrmonth free bluetooth orang avail soni nokia motorola phone call mobileupdnumbr numbr callnumbroptout nnumbrdx',
#   1),
#  ('took mr owl numbr lick', 0),
#  ('custom place call', 0),
#  ('mm time dont like fun', 0),
#  ('numbrmth half price orang line rental latest camera phone numbr free phone numbrmth call mobilesdirect free numbr updat ornumbrstoptxt',
#   1),
#  ('yup lunch buffet u eat alreadi', 0),
#  ('huh late fr dinner', 0),
#  ('hey sat go intro pilat kickbox', 0),
#  ('morn ok', 0),
#  ('ye think offic lap room think last day didnt shut', 0),
#  ('pick bout numbrish time go', 0),
#  ('perform award calcul everi two month current one month period', 0),
#  ('actual sleep still might u call back text grnumbr rock si send u text wen wake',
#   0),
#  ('alway put busi put pictur ass facebook one open peopl ever met would think pictur room would hurt make feel violat',
#   0),
#  ('good even sir al salam wahleykkum share happi news grace god got offer tayseer tissco join hope fine inshah allah meet sometim rakhesh visitor india',
#   0),
#  ('hmmm k want chang field quickli da wanna get system administr network administr',
#   0),
#  ('free rington text first numbr poli text get numbr true tone help numbr numbr numbr numbrst free tone numbrxmoneysymbnumbrpw emoneysymbnd txt stop',
#   1),
#  ('dear chechi talk', 0),
#  ('hair cream ship', 0),
#  ('none happen til get though', 0),
#  ('yep great loxahatch xma tree burn lt gt start hour', 0),
#  ('haha get use drive usf man know lot stoner', 0),
#  ('well slightli disastr class pm fav darl hope day ok coff wld good stay late tomorrow time place alway',
#   0),
#  ('hello good week fanci drink someth later', 0),
#  ('headin toward busetop', 0),
#  ('messag text miss sender name miss number miss sent date miss miss u lot everyth miss sent via fullonsm com',
#   0),
#  ('come room point iron plan weekend', 0),
#  ('co want thing', 0),
#  ('oki go yan jiu skip ard oso go cine den go mrt one blah blah blah', 0),
#  ('bring home wendi', 0),
#  ('numbr date servic cal l numbr boxnumbrsknumbrch', 1),
#  ('whatsup dont u want sleep', 0),
#  ('alright new goal', 0),
#  ('free entri moneysymbnumbr weekli competit text word win numbr numbr c www txttowin co uk',
#   1),
#  ('alright head minut text meet', 0),
#  ('send logo numbr ur lover numbr name join heart txt love namenumbr namenumbr mobno eg love adam eve numbr numbr yahoo poboxnumbrwnumbrwq txtno numbr ad numbrp',
#   1),
#  ('ye last week take live call', 0),
#  ('someon contact date servic enter phone fanci find call landlin numbr poboxnumbrnnumbrtfnumbrp',
#   1),
#  ('siva hostel aha', 0),
#  ('urgent mobil number award moneysymbnumbr prize guarant call numbr land line claim numbr valid numbrhr',
#   1),
#  ('send ur friend receiv someth ur voic speak express numbr childish numbr naughti numbr sentiment numbr rowdi numbr ful attitud numbr romant numbr shi numbr attract numbr funni lt gt irrit lt gt lovabl repli',
#   0),
#  ('ok ok guess', 0),
#  ('aathi dear', 0),
#  ('pain urin thing el', 0),
#  ('numbr esplanad ü mind give lift co got car today', 0),
#  ('wnt buy bmw car urgent vri urgent hv shortag lt gt lac sourc arng di amt lt gt lac prob',
#   0),
#  ('home watch tv lor', 0),
#  ('usual take fifteen fuck minut respond ye question', 0),
#  ('congrat nokia numbr video camera phone call numbr call cost numbrppm ave call numbrmin vari mobil numbr close numbr post bcmnumbr ldn wcnumbrnnumbrxx',
#   1),
#  ('book ticket pongal', 0),
#  ('avail like right around hillsborough amp lt gt th', 0),
#  ('messag sent askin lt gt dollar shoul pay lt gt lt gt', 0),
#  ('ask g iouri told stori like ten time alreadi', 0),
#  ('long appleb fuck take', 0),
#  ('hi hope u get txt journey hasnt gd numbr min late think', 0),
#  ('like love arrang', 0),
#  ('ye realli great bhaji told kalli best cricket sachin world tough get', 0),
#  ('suppo wake gt', 0),
#  ('oic saw tot din c found group liao', 0),
#  ('sorri call later', 0),
#  ('hey hey wereth monkeespeopl say monkeyaround howdi gorgeou howu doin foundurself jobyet sausag love jen xxx',
#   0),
#  ('sorri batteri die come get gram place', 0),
#  ('well done blimey exerci yeah kinda rememb wot hmm', 0),
#  ('wont get concentr dear know mind everyth', 0),
#  ('lol made plan new year', 0),
#  ('numbr min later k', 0),
#  ('hank lotsli', 0),
#  ('thank hope good day today', 0),
#  ('k k detail want transfer acc enough', 0),
#  ('ok tell stay yeah tough optimist thing improv month', 0),
#  ('loan purpo moneysymbnumbr moneysymbnumbr numbr homeown tenant welcom previou refu still help call free numbr numbr text back help',
#   1),
#  ('si si think ill go make oreo truffl', 0),
#  ('look ami ure beauti intellig woman like u lot know u like like worri', 0),
#  ('hope result consist intellig kind start ask practicum link keep ear open best ttyl',
#   0),
#  ('numbr call cost guess isnt bad miss ya need ya want ya love ya', 0),
#  ('go thru differ feel waver deci cope individu time heal everyth believ', 0),
#  ('u go phone gonna die stay', 0),
#  ('great never better day give even reason thank god', 0),
#  ('upgrdcentr orang custom may claim free camera phone upgrad loyalti call numbr numbr numbr offer end numbrth juli c appli opt avail',
#   1),
#  ('sorri call later ok bye', 0),
#  ('ok way railway', 0),
#  ('great princess love give receiv oral doggi style fave posit enjoy make love lt gt time per night',
#   0),
#  ('put stuff road keep get slipperi', 0),
#  ('go ride bike', 0),
#  ('yup need ju wait numbr e rain numbr stop', 0),
#  ('mani compani tell languag', 0),
#  ('okmail dear dave final notic collect numbr tenerif holiday numbr cash award call numbr landlin tc sae boxnumbr cwnumbrwx numbrppm',
#   1),
#  ('long sinc scream princess', 0),
#  ('noth meant money enter account bank remov flat rate someon transfer lt gt account lt gt dollar got remov bank differ charg also differ sure trust numbrja person send account detail co',
#   0),
#  ('want numbr get laid tonight want real dog locat sent direct numbr ur mob join uk largest dog network txting moan numbrnyt ecnumbra numbrp msg numbrp',
#   1),
#  ('nice line said broken heart plz cum numbr time infront wise trust u good numbrt',
#   0),
#  ('ok gonna head usf like fifteen minut', 0),
#  ('love aathi love u lot', 0),
#  ('tension ah machi problem', 0),
#  ('k pick anoth numbrth done', 0),
#  ('guy get back g said think stay mcr', 0),
#  ('almost see u sec', 0),
#  ('yo carlo friend alreadi ask work weekend', 0),
#  ('watch tv lor', 0),
#  ('thank babi cant wait tast real thing', 0),
#  ('chang fb jaykwon thuglyf falconerf', 0),
#  ('win realli numbr side long time', 0),
#  ('free messag activ numbr free text messag repli messag word free term condit visit www numbr com',
#   1),
#  ('dear reach railway happen', 0),
#  ('depend qualiti want type sent boy fade glori numbr want ralph mayb numbr',
#   0),
#  ('think fix send test messag', 0),
#  ('sorri man account dri would want could trade back half could buy shit credit card',
#   0),
#  ('congrat numbr year special cinema pass numbr call numbr c suprman v matrixnumbr starwarsnumbr etc numbr free bxnumbr ipnumbr numbrw numbrpm dont miss',
#   1),
#  ('sorri meet call later', 0),
#  ('class lt gt reunion', 0),
#  ('free call', 0),
#  ('got meh', 0),
#  ('nope think go monday sorri repli late', 0),
#  ('told accentur confirm true', 0),
#  ('kate jackson rec center numbrish right', 0),
#  ('dear reach room', 0),
#  ('fight world easi u either win lose bt fightng somenumbr close u dificult u lose u lose u win u still lose',
#   0),
#  ('ü come', 0),
#  ('check nuerologist', 0),
#  ('lolnic went fish water', 0),
#  ('numbr congratul week competit draw u moneysymbnumbr prize claim call numbr bnumbr cs stop sm numbr numbr numbrppm',
#   1),
#  ('wait e car dat bore wat co wait outsid got noth numbr home stuff watch tv wat',
#   0),
#  ('mayb westshor hyde park villag place near hou', 0),
#  ('know anthoni bring money school fee pay rent stuff like need help friend need',
#   0),
#  ('signif', 0),
#  ('opinion numbr numbr jada numbr kusruthi numbr lovabl numbr silent numbr spl charact numbr matur numbr stylish numbr simpl pl repli',
#   0),
#  ('numbr latest g still scroung ammo want give new ak tri', 0),
#  ('prabha soryda reali frm heart sori', 0),
#  ('lol ok forgiven', 0),
#  ('jst chang tat', 0),
#  ('guarant latest nokia phone numbrgb ipod mpnumbr player moneysymbnumbr prize txt word collect numbr ibhltd ldnwnumbrh numbrp mtmsgrcvdnumbr',
#   1),
#  ('competit', 0),
#  ('boltblu tone numbrp repli poli mono eg polynumbr numbr cha cha slide numbr yeah numbr slow jamz numbr toxic numbr come stop numbr tone txt',
#   1),
#  ('credit top http www bubbletext com renew pin tgxxrz', 1),
#  ('way transport less problemat sat night way u want ask n join bday feel free need know definit book fri',
#   0),
#  ('usual person unconsci children adult may behav abnorm call', 0),
#  ('ebay might less elsewh', 0),
#  ('shall come get pickl', 0),
#  ('gonna go get taco', 0),
#  ('rude campu', 0),
#  ('urgent mobil award moneysymbnumbr numbr bonu caller prize numbr numbr numbr numbrnd attempt contact call numbr numbr numbr boxnumbrqu',
#   1),
#  ('hi b ard numbr christma enjoy n merri x', 0),
#  ('today offer claim ur moneysymbnumbr worth discount voucher text ye numbr savamob member offer mobil cs numbr moneysymbnumbr sub numbr unsub repli x',
#   1),
#  ('ye pretti ladi like singl', 0),
#  ('reciev tone within next numbrhr term condit plea see channel u teletext pg numbr',
#   1),
#  ('jay say doubl faggot', 0),
#  ('privat numbr account statement numbr show numbr un redeem point call numbr identifi code numbr expir numbr numbr numbr',
#   1),
#  ('today sunday sunday holiday work', 0),
#  ('gudnit tc practic go', 0),
#  ('late', 0),
#  ('call hope lnumbrr malaria know miss guy miss bani big pl give love especi great day',
#   0),
#  ('good afternoon love goe day hope mayb got lead job think boytoy send passion kiss across sea',
#   0),
#  ('probabl gonna see later tonight lt', 0),
#  ('mayb fat finger press button know', 0),
#  ('ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#   0),
#  ('tirupur da start offic call', 0),
#  ('www applausestor com monthlysubscript numbrp msg maxnumbr month csc web agenumbr numbrstop txt stop',
#   1),
#  ('famou quot develop abil listen anyth uncondit without lose temper self confid mean marri',
#   0),
#  ('go colleg pa el ill come self pa', 0),
#  ('numbr oclock mine bash flat plan', 0),
#  ('girl stay bed girl need recoveri time id rather pass fun coop bed', 0),
#  ('special', 0),
#  ('know need get hotel got invit apolog cali sweet come english bloke weddin',
#   0),
#  ('sorri took long omw', 0),
#  ('wait lt gt min', 0),
#  ('ok give numbr minut think see btw alibi cut hair whole time', 0),
#  ('imagin final get sink bath put pace mayb even eat left also imagin feel cage cock surround bath water remind alway enjoy cuck',
#   0),
#  ('hurri weed defici like three day', 0),
#  ('sure get acknowledg astoundingli tactless gener faggi demand blood oath fo',
#   0),
#  ('ok everi night take warm bath drink cup milk see work magic still need loo weight know',
#   0),
#  ('look fri pan case cheap book perhap silli fri pan like book', 0),
#  ('well uv cau mutat sunscreen like essenti theseday', 0),
#  ('lunch onlin', 0),
#  ('know friend alreadi told', 0),
#  ('hi princess thank pic pretti', 0),
#  ('aiyo u alway c ex one dunno abt mei repli first time u repli fast lucki workin huh got bao ur sugardad ah gee',
#   0),
#  ('hi msg offic', 0),
#  ('thanx numbr e browni v nice', 0),
#  ('geeeee love much bare stand', 0),
#  ('gent tri contact last weekend draw show moneysymbnumbr prize guarant call numbr claim code knumbr valid numbrhr numbrppm',
#   1),
#  ('fuck babe miss alreadi know let send money toward net need want crave', 0),
#  ('ill call u numbrmrw ninish address icki american freek wont stop callin numbr bad jen k eh',
#   0),
#  ('oooh bed ridden ey think', 0),
#  ('anyway go gym whatev love smile hope ok good day babe miss much alreadi',
#   0),
#  ('love daddi make scream pleasur go slap ass dick', 0),
#  ('wot u wanna missi', 0),
#  ('yar lor wait numbr mum numbr finish sch lunch lor whole morn stay home clean room room quit clean hee',
#   0),
#  ('know lab goggl went', 0),
#  ('open door', 0),
#  ('wait call', 0),
#  ('nope wait sch numbr daddi', 0),
#  ('numbr numbr cash numbr numbr prize claim callnumbr', 1),
#  ('tire argu week week want', 0),
#  ('ü wait numbr sch finish ard numbr', 0),
#  ('mobil number moneysymbnumbr claim call us back ring claim hot line numbr',
#   1),
#  ('arngd marriag u r walkin unfortuntli snake bite u bt love marriag danc frnt snake amp sayin bite bite',
#   0),
#  ('huh earli ü dinner outsid izzit', 0),
#  ('ok anyway need chang said', 0),
#  ('tri contact repli offer numbr min numbr textand new video phone call numbr repli free deliveri tomorrow',
#   1),
#  ('ex wife abl kid want kid one day', 0),
#  ('scotland hope show jjc tendenc take care live dream', 0),
#  ('tell u headach want use numbr hour sick time', 0),
#  ('dun thk quit yet hmmm go jazz yogasana oso go meet em lesson den', 0),
#  ('pete plea ring meiv hardli gotani credit', 0),
#  ('ya srsli better yi tho', 0),
#  ('meet call later', 0),
#  ('ur chanc win moneysymbnumbr wkli shop spree txt shop numbr c www txt numbr shop com custcar numbr numbrxnumbrp wk',
#   1),
#  ('special select receiv numbr pound award call numbr line close cost numbrppm numbr cs appli ag promo',
#   1),
#  ('privat numbr account statement numbr show numbr un redeem point call numbr identifi code numbr expir numbr numbr numbr',
#   1),
#  ('still grand prix', 0),
#  ('met stranger choo friend long world stand friendship never end let friend forev gud nitz',
#   0),
#  ('great', 0),
#  ('gud mrng dear nice day', 0),
#  ('import custom servic announc call freephon numbr numbr numbr', 1),
#  ('exhaust train morn much wine pie sleep well', 0),
#  ('go buy mum present ar', 0),
#  ('mind blastin tsunami occur rajnik stop swim indian ocean', 0),
#  ('u send home first ok lor readi yet', 0),
#  ('speak cash yet', 0),
#  ('happi come noon', 0),
#  ('meet lunch la', 0),
#  ('take care n get well soon', 0),
#  ('xclusiv clubsaisai numbrmorow numbr numbr soir special zouk nichol pari free rose numbr ladi info numbr numbr',
#   1),
#  ('meant say cant wait see u get bore bridgwat banter', 0),
#  ('neva mind ok', 0),
#  ('fine imma get drink somethin want come find', 0),
#  ('numbr day kick euronumbr u kept date latest news result daili remov send get txt stop numbr',
#   1),
#  ('valentin game send di msg ur friend numbr answer r someon realli love u que colour suit best rpli',
#   0),
#  ('mani depend', 0),
#  ('thanxnumbr today cer nice numbr catch ave numbr find time often oh well take care c u soon c',
#   0),
#  ('call said choo futur', 0),
#  ('happi valentin day know earli hundr handsom beauti wish thought finish aunti uncl numbrst',
#   0),
#  ('like v shock leh co tell shuhui like tell leona also like dat almost know liao got ask abt ur reaction lor',
#   0),
#  ('famili happi', 0),
#  ('come n pick ü come immedi aft ur lesson', 0),
#  ('let snow let snow kind weather bring ppl togeth friendship grow', 0),
#  ('dear got lt gt dollar hi hi', 0),
#  ('good word word may leav u dismay mani time', 0),
#  ('make sure alex know birthday fifteen minut far concern', 0),
#  ('sorri got thing may pub later', 0),
#  ('nah straight bring bud drink someth actual littl use straight cash', 0),
#  ('haha good hear offici paid market numbrth', 0),
#  ('mani lick take get center tootsi pop', 0),
#  ('yup thk r e teacher said make face look longer darren ask numbr cut short',
#   0),
#  ('new textbuddi chat numbr horni guy ur area numbr numbrp free numbr receiv search postcod gaytextbuddi com txt one name numbr',
#   1),
#  ('today vodafon number end numbr select receiv moneysymbnumbr award number match call numbr receiv moneysymbnumbr award',
#   1),
#  ('plea dont say like hi hi hi', 0),
#  ('thank u', 0),
#  ('oh forward messag thought send', 0),
#  ('got seventeen pound seven hundr ml hope ok', 0),
#  ('dear voucher holder numbr claim week offer pc go http www e tlp co uk expressoff ts cs appli numbr stop text txt stop numbr',
#   1),
#  ('n funni', 0),
#  ('sweetheart hope kind day one load reason smile biola', 0),
#  ('ü login dat time dad fetch ü home', 0),
#  ('shower babi', 0),
#  ('askd u question hour answer', 0),
#  ('well imma definit need restock thanksgiv let know', 0),
#  ('said kiss kiss sound effect gorgeou man kind person need smile brighten day',
#   0),
#  ('probabl gonna swing wee bit', 0),
#  ('ya nice readi thursday', 0),
#  ('allo brave buse taken train triumph mean b ham jolli good rest week', 0),
#  ('watch cartoon listen music amp eve go templ amp church u', 0),
#  ('mind ask happen dont say uncomfort', 0),
#  ('privat numbr account statement show numbr un redeem point call numbr identifi code numbr expir numbr numbr numbr',
#   1),
#  ('prob send email', 0),
#  ('numbr numbr cash numbr numbr prize claim callnumbr c rstm swnumbr numbrss numbrppm',
#   1),
#  ('cool sometim slow gentl sonetim rough hard', 0),
#  ('gonna say sorri would normal start panic time sorri see tuesday', 0),
#  ('wait know wesley town bet hella drug', 0),
#  ('fine miss much', 0),
#  ('u got person stori', 0),
#  ('tell drug dealer get impati', 0),
#  ('sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#   0),
#  ('place man', 0),
#  ('doesnt make sen take unless free need know wikipedia com', 0),
#  ('numbr numbr premium phone servic call numbr', 1),
#  ('sea lay rock rock envelop envelop paper paper numbr word', 0),
#  ('mum repent', 0),
#  ('sorri go home first daddi come fetch ü later', 0),
#  ('leav de start prepar next', 0),
#  ('ye babi studi posit kama sutra', 0),
#  ('en chikku nang bakra msg kalstiya tea coff', 0),
#  ('carlo minut still need buy', 0),
#  ('pay lt decim gt lakh', 0),
#  ('good even ttyl', 0),
#  ('u receiv msg', 0),
#  ('ho ho big belli laugh see ya tomo', 0),
#  ('sm ac sunnumbr post hello seem cool want say hi hi stop send stop numbr',
#   1),
#  ('get ur numbrst rington free repli msg tone grnumbr top numbr tone phone everi week moneysymbnumbr per wk numbr opt send stop numbr numbr',
#   1),
#  ('ditto worri say anyth anymor like said last night whatev want peac', 0),
#  ('got lt gt way could pick', 0),
#  ('dont knw pa drink milk', 0),
#  ('mayb say hi find got card great escap wetherspoon', 0),
#  ('piggi r u awak bet u still sleep go numbr lunch', 0),
#  ('cau freaki lol', 0),
#  ('miss call cau yell scrappi miss u wait u come home lone today', 0),
#  ('hex place talk explain', 0),
#  ('ü log numbr wat sdrybnumbri', 0),
#  ('xy go numbr e lunch', 0),
#  ('hi sue numbr year old work lapdanc love sex text live bedroom text sue numbr textop gnumbr numbrda numbrppmsg numbr',
#   1),
#  ('want ask ü wait numbr finish lect co lect finish hour anyway', 0),
#  ('finish work yet', 0),
#  ('everi king cri babi everi great build map imprtant u r today u wil reach tomorw gud ninumbr',
#   0),
#  ('dear cherthala case u r come cochin pl call bfore u start shall also reach accordingli tell day u r come tmorow engag holiday',
#   0),
#  ('thank love torch bold', 0),
#  ('forward numbr plea call numbr immedi urgent messag wait', 1),
#  ('farm open', 0),
#  ('sorri troubl u buy numbrd dad numbr numbr numbr numbr big numbr small sat n sun thanx',
#   0),
#  ('sister law hope great month say hey abiola', 0),
#  ('purcha stuff today mail po box number', 0),
#  ('ah poop look like ill prob send laptop get fix cuz gpu problem', 0),
#  ('good good job like entrepreneur', 0),
#  ('aight close still around alex place', 0),
#  ('meet corpor st outsid gap see mind work', 0),
#  ('mum ask ü buy food home', 0),
#  ('k u also dont msg repli msg', 0),
#  ('much r ü pay', 0),
#  ('sorri call later', 0),
#  ('import prevent dehydr give enough fluid', 0),
#  ('bit weird even suppo happen good idea sure pub', 0),
#  ('true dear sat pray even felt sm time', 0),
#  ('think get away trek long famili town sorri', 0),
#  ('wanna gym harri', 0),
#  ('quit late lar ard numbr anyway wun b drivin', 0),
#  ('review keep fantast nokia n gage game deck club nokia go numbr www cnupdat com newslett unsubscrib alert repli word',
#   1),
#  ('numbrmth half price orang line rental latest camera phone numbr free phone numbrmth call mobilesdirect free numbr updat ornumbrstoptxt cs',
#   1),
#  ('height confid aeronaut professor wer calld amp wer askd numbr sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt numbr didnt move said made student wont even start datz confid',
#   0),
#  ('seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#   0),
#  ('numbr numbram numbrpm cost numbrp', 1),
#  ('save stress person dorm account send account detail money sent', 0),
#  ('also know lunch menu da know', 0),
#  ('stuff sell tell', 0),
#  ('numbr urgent numbrnd attempt contact u u moneysymbnumbr call numbr bnumbr numbr csbcmnumbrwcnumbrnnumbrxx callcost numbrppm mobilesvari maxmoneysymbnumbr numbr',
#   1),
#  ('book lesson msg call work sth go get spec membership pxnumbr', 0),
#  ('guarant moneysymbnumbr cash moneysymbnumbr prize claim yr prize call custom servic repr numbr numbram numbrpm',
#   1),
#  ('macha dont feel upset assum mindset believ one even wonder plan us let life begin call anytim',
#   0),
#  ('oh send address', 0),
#  ('fine anytim best', 0),
#  ('wondar full flim', 0),
#  ('ya even cooki jelli', 0),
#  ('world run still mayb feel admit mad correct let call life keep run world may u r also run let run',
#   0),
#  ('got look scrumptiou daddi want eat night long', 0),
#  ('co lar ba dao ok numbr pm lor u never ask go ah said u would ask fri said u ask today',
#   0),
#  ('alright omw gotta chang order halfnumbrth', 0),
#  ('exactli anyway far jide studi visit', 0),
#  ('dunno u ask', 0),
#  ('email alertfrom jeri stewart numbrkbsubject low cost prescripiton drvgsto listen email call numbr',
#   1),
#  ('spring come earli yay', 0),
#  ('lol feel bad use money take steak dinner', 0),
#  ('even u dont get troubl convinc tel twice tel neglect msg dont c read dont repli',
#   0),
#  ('leav qatar tonit search opportun went fast pl add ur prayer dear rakhesh',
#   0),
#  ('one talk', 0),
#  ('thank look realli appreci', 0),
#  ('hi custom loyalti offer new nokianumbr mobil moneysymbnumbr txtauction txt word start numbr get numbrt ctxt tc numbrp mtmsg',
#   1),
#  ('wish', 0),
#  ('haha mayb u rite u know well da feel like someon gd lor u faster go find one gal group attach liao',
#   0),
#  ('ye glad made', 0),
#  ('well littl time thing good time ahead', 0),
#  ('got room soon put clock back til numbr shout everyon get reali numbr wahay anoth hour bed',
#   0),
#  ('ok may free gym', 0),
#  ('men like shorter ladi gaze eye', 0),
#  ('dunno ju say go lido time numbr', 0),
#  ('promi take good care princess run plea send pic get chanc ttyl', 0),
#  ('u subscrib best mobil content servic uk moneysymbnumbr per numbr day send stop numbr helplin numbr',
#   1),
#  ('reason spoken year anyway great week best exam', 0),
#  ('monday next week give full gist', 0),
#  ('realiz numbr year thousand old ladi run around tattoo', 1),
#  ('import custom servic announc premier', 1),
#  ('dont gimm lip caveboy', 0),
#  ('get librari', 0),
#  ('reali sorri recogni number confu r u plea', 0),
#  ('didnt holla', 0),
#  ('cant think anyon spare room top head', 0),
#  ('faith make thing possibl hope make thing work love make thing beauti may three christma merri christma',
#   0),
#  ('u made appoint', 0),
#  ('call carlo phone vibrat act might hear text', 0),
#  ('romant pari numbr night numbr flight moneysymbnumbr book numbr next year call numbrt cs appli',
#   1),
#  ('grandma oh dear u still ill felt shit morn think hungov anoth night leav sat',
#   0),
#  ('urgent ur moneysymbnumbr guarant award still unclaim call numbr closingdatenumbr numbr numbr claimcod mnumbrmnumbr moneysymbnumbrpmmorefrommobilenumbrbremov mobypoboxnumbrlsnumbryf',
#   1),
#  ('noth ju tot u would ask co u ba gua went mt faber yest yest ju went alreadi mah today go ju call lor',
#   0),
#  ('wish famili merri x happi new year advanc', 0),
#  ('ur award citi break could win moneysymbnumbr summer shop spree everi wk txt store numbr skilgm tscsnumbrwinawk agenumbr moneysymbnumbrperwksub',
#   1),
#  ('nt goin got somethin unless meetin numbr dinner lor haha wonder go ti time',
#   0),
#  ('sorri call later', 0),
#  ('cant pick phone right pl send messag', 0),
#  ('lol know dramat school alreadi close tomorrow appar drive inch snow suppo get',
#   0),
#  ('get anywh damn job hunt', 0),
#  ('lol u drunkard hair moment yeah still numbr tonight wat plan', 0),
#  ('idc get weasel way shit twice row', 0),
#  ('wil lt gt minut got space', 0),
#  ('sleep surf', 0),
#  ('thank pick trash', 0),
#  ('go tell friend sure want live smoke much spend hour beg come smoke', 0),
#  ('hi kate love see tonight ill phone tomorrow got sing guy gave card xxx', 0),
#  ('happi new year dear brother realli miss got number decid send text wish happi abiola',
#   0),
#  ('mean get door', 0),
#  ('opinion numbr numbr jada numbr kusruthi numbr lovabl numbr silent numbr spl charact numbr matur numbr stylish numbr simpl pl repli',
#   0),
#  ('hmmm thought said numbr hour slave numbr late punish', 0),
#  ('beerag', 0),
#  ('import custom servic announc premier call freephon numbr numbr numbr', 1),
#  ('dont think turn like randomlli within numbrmin open', 0),
#  ('suppo make still town though', 0),
#  ('time fix spell sometim get complet diff word go figur', 0),
#  ('ever thought live good life perfect partner txt back name age join mobil commun numbrp sm',
#   1),
#  ('numbr free top polyphon tone call numbr nation rate get toppoli tune sent everi week text subpoli numbr moneysymbnumbr per pole unsub numbr',
#   1),
#  ('gud mrng dear hav nice day', 0),
#  ('hope enjoy game yesterday sorri touch pl know fondli bein thot great week abiola',
#   0),
#  ('e best numbr ur drive tmr', 0),
#  ('u dogbreath sound like jan c al', 0),
#  ('omg want scream weigh lost weight woohoo', 0),
#  ('gener one uncount noun u dictionari piec research', 0),
#  ('realli get hang around', 0),
#  ('orang custom may claim free camera phone upgrad loyalti call numbr numbr numbr offer end numbrthmarch c appli opt availa',
#   1),
#  ('petey boy wherear friendsar thekingshead come canlov nic', 0),
#  ('ok msg u bnumbr leav hou', 0),
#  ('gimm lt gt minut ago', 0),
#  ('last chanc claim ur moneysymbnumbr worth discount voucher today text shop numbr savamob offer mobil cs savamob poboxnumbr mnumbruz moneysymbnumbr sub numbr',
#   1),
#  ('appt lt time gt fault u listen told u twice', 0),
#  ('free numbrst week nonumbr nokia tone numbr ur mobil everi week txt nokia numbr get txting tell ur mate www getz co uk pobox numbr wnumbrwq numbr normnumbrp tone',
#   1),
#  ('guarant moneysymbnumbr award even moneysymbnumbr cashto claim ur award call free numbr numbr numbr stop getstop numbr php rgnumbr numbrjx',
#   1),
#  ('k numbr', 0),
#  ('dled numbrd imp', 0),
#  ('sure make sure know smokin yet', 0),
#  ('boooo alway work quit', 0),
#  ('take half day leav bec well', 0),
#  ('ugh wanna get bed warm', 0),
#  ('nervou lt gt', 0),
#  ('ring come guy costum gift futur yowif hint hint', 0),
#  ('congratul ur award either moneysymbnumbr cd gift voucher free entri numbr moneysymbnumbr weekli draw txt music numbr tnc www ldew comnumbrwinnumbrppmxnumbragenumbr',
#   1),
#  ('borrow ur bag ok', 0),
#  ('u outbid simonwatsonnumbr shinco dvd plyr numbr bid visit sm ac smsreward numbr end bid notif repli end',
#   1),
#  ('boytoy miss happen', 0),
#  ('lot use one babe model help youi bring match', 0),
#  ('also bring galileo dobbi', 0),
#  ('respond', 0),
#  ('boo babe u enjoyin yourjob u seem numbr b gettin well hunni hope ure ok take care llspeak numbru soonlot lovem xxxx',
#   0),
#  ('good afternoon starshin boytoy crave yet ach fuck sip cappuccino miss babe tea kiss',
#   0),
#  ('road cant txt', 0),
#  ('smsservic yourinclu text credit pl goto www comuk net login numbrqxjnumbr unsubscrib stop extra charg help numbr comuk numbr cmnumbr numbra',
#   1),
#  ('numbrp numbr alfi moon children need song ur mob tell ur mnumbr txt tone chariti numbr nokia poli chariti poli zed numbr profit numbr chariti',
#   1),
#  ('good even ttyl', 0),
#  ('hmm bit piec lol sigh', 0),
#  ('hahaha use brain dear', 0),
#  ('hey got mail', 0),
#  ('sorri light turn green meant anoth friend want lt gt worth may around', 0),
#  ('thank yesterday sir wonder hope enjoy burial mojibiola', 0),
#  ('u secret admir reveal think u r special call numbr opt repli reveal stop numbr per msg recd cust care numbr',
#   1),
#  ('hi mate rv u hav nice hol messag numbr say hello coz sent u numbr age start drive stay road rvx',
#   0),
#  ('dear voucher holder claim week offer pc plea go http www e tlp co uk expressoff ts cs appli stop text txt stop numbr',
#   1),
#  ('thank much skype wit kz sura didnt get pleasur compani hope good given ultimatum oh countin aburo enjoy messag sent day ago',
#   0),
#  ('sure result offer', 0),
#  ('good morn dear great amp success day', 0),
#  ('want numbr anytim network min numbr text new video phone five pound per week call numbr repli deliveri tomorrow',
#   1),
#  ('sir late pay rent past month pay moneysymb lt gt charg felt would inconsid nag someth give great cost didnt speak howev recess wont abl pay charg month henc askin well ahead month end plea help thank',
#   0),
#  ('tri contact offer new video phone numbr anytim network min half price rental camcord call numbr repli deliveri wed',
#   1),
#  ('last chanc numbr claim ur moneysymbnumbr worth discount voucher text ye numbr savamob member offer mobil cs numbr moneysymbnumbr sub numbr remov txt x stop',
#   1),
#  ('luv u soo much u understand special u r numbr ring u numbrmorrow luv u xxx',
#   0),
#  ('pl send comprehen mail pay much', 0),
#  ('prashanthettan mother pass away last night pray famili', 0),
#  ('urgent call numbr landlin complimentari numbr ibiza holiday numbr numbr cash await collect sae cs po box numbr sknumbr numbrwp numbr ppm numbr',
#   1),
#  ('k k go', 0),
#  ('meanwhil shit suit xavier decid give us lt gt second warn samantha come play jay guitar impress shit also think doug realiz live anymor',
#   0),
#  ('stomach thru much trauma swear eat better lose weight', 0),
#  ('offic matter msg call break', 0),
#  ('yeah bare enough room two us x mani fuck shoe sorri man see later', 0),
#  ('today offer claim ur moneysymbnumbr worth discount voucher text ye numbr savamob member offer mobil cs numbr moneysymbnumbr sub numbr unsub repli x',
#   1),
#  ('u reach orchard alreadi u wan numbr go buy ticket first', 0),
#  ('real babi want bring inner tigress', 0),
#  ('da run activ full version da', 0),
#  ('ah poor babi hope urfeel bettersn luv probthat overdo work hey go care spk numbr u sn lot lovejen xxx',
#   0),
#  ('stop stori told return say order', 0),
#  ('talk sexi make new friend fall love world discreet text date servic text vip numbr see could meet',
#   1),
#  ('go take babe', 0),
#  ('hai ana tomarrow come morn lt decim gt ill sathi go rto offic repli came home',
#   0),
#  ('spoon okay', 0),
#  ('say somebodi name tampa', 0),
#  ('work go min', 0),
#  ('brother geniu', 0),
#  ('sorri guess whenev get hold connect mayb hour two text', 0),
#  ('u find time bu coz need sort stuff', 0),
#  ('dude ive see lotta corvett late', 0),
#  ('congratul ur award either yr suppli cd virgin record mysteri gift guarant call numbr ts cs www smsco net moneysymbnumbrpm approx numbrmin',
#   1),
#  ('consid wall bunker shit import never play peac guess place high enough matter',
#   0),
#  ('privat numbr account statement numbr xxxxxx show numbr un redeem point call numbr identifi code numbr expir numbr numbr numbr',
#   1),
#  ('hello need posh bird chap user trial prod champney put need address dob asap ta r',
#   1),
#  ('u want xma numbr free text messag new video phone half price line rental call free numbr numbr find',
#   1),
#  ('well offici philosoph hole u wanna call home readi save', 0),
#  ('go good problem still need littl experi understand american custom voic',
#   0),
#  ('text drop x', 0),
#  ('ugh long day exhaust want cuddl take nap', 0),
#  ('talk atleast day otherwi miss best friend world shakespear shesil lt gt',
#   0),
#  ('shop till u drop either numbrk numbrk moneysymbnumbr cash moneysymbnumbr travel voucher call numbr ntt po box crnumbrbt fixedlin cost numbrppm mobil vari',
#   1),
#  ('castor need see someth', 0),
#  ('sunshin quiz wkli q win top soni dvd player u know countri liverpool play mid week txt ansr numbr moneysymbnumbr sp tyron',
#   1),
#  ('u secret admir look numbr make contact u find r reveal think ur special call numbr',
#   1),
#  ('u secret admir look numbr make contact u find r reveal think ur special call numbr stopsm numbr',
#   1),
#  ('remind download content alreadi paid goto http doit mymobi tv collect content',
#   1),
#  ('see knew give break time woul lead alway want miss curfew gonna gibe til one midnight movi gonna get til numbr need come home need getsleep anyth need b studdi ear train',
#   0),
#  ('love give massag use lot babi oil fave posit', 0),
#  ('dude go sup', 0),
#  ('yoyyooo u know chang permiss drive mac usb flash drive', 0),
#  ('gibb unsold mike hussey', 0),
#  ('like talk pa abl dont know', 0),
#  ('dun cut short leh u dun like ah fail quit sad', 0),
#  ('unbeliev faglord', 0),
#  ('wife knew time murder exactli', 0),
#  ('ask princess', 0),
#  ('great princess think', 0),
#  ('nutter cutter ctter cttergg cttargg ctargg ctagg ie', 0),
#  ('ok noe u busi realli bore msg u oso dunno wat colour choo numbr one', 0),
#  ('g class earli tomorrow thu tri smoke lt gt', 0),
#  ('superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#   0),
#  ('hope good week check', 0),
#  ('use hope agent drop sinc book thing year whole boston nyc experi', 0),
#  ('thursday night yeah sure thing work', 0),
#  ('free rington wait collect simpli text password mix numbr verifi get usher britney fml po box numbr mknumbr numbrh numbrppw numbr',
#   1),
#  ('probabl money worri thing come due sever outstand invoic work two three month ago',
#   0),
#  ('possibl teach', 0),
#  ('wonder phone batteri went dead tell love babe', 0),
#  ('love smell bu tobacco', 0),
#  ('get worri derek taylor alreadi assum worst', 0),
#  ('hey charl sorri late repli', 0),
#  ('lastest stereophon marley dizz racal libertin stroke win nookii game flirt click themob wap bookmark text wap numbr',
#   1),
#  ('give plu said grinul greet whenev speak', 0),
#  ('white fudg oreo store', 0),
#  ('januari male sale hot gay chat cheaper call numbr nation rate numbrp min cheap numbrp min peak stop text call numbr numbrp min',
#   1),
#  ('love come took long leav zaher got word ym happi see sad left miss', 0),
#  ('sorri hurt', 0),
#  ('feel nauseou piss eat sweet week cau today plan pig diet week hungri', 0),
#  ('ok lor earli still project meet', 0),
#  ('call da wait call', 0),
#  ('could ask carlo could get anybodi el chip', 0),
#  ('actual send remind today wonder weekend', 0),
#  ('peopl see msg think iam addict msging wrong bcoz know iam addict sweet friend bslvyl',
#   0),
#  ('hey gave photo regist drive ah tmr wanna meet yck', 0),
#  ('dont talk ever ok word', 0),
#  ('u wana see', 0),
#  ('way school pl send ashley number', 0),
#  ('shall fine avalarr hollalat', 0),
#  ('went attend anoth two round today still reach home', 0),
#  ('actual delet old websit blog magicalsong blogspot com', 0),
#  ('k wait chikku il send aftr lt gt min', 0),
#  ('diet ate numbr mani slice pizza yesterday ugh alway diet', 0),
#  ('k give kvb acc detail', 0),
#  ('oh come ah', 0),
#  ('money r lucki winner numbr claim prize text money numbr numbr moneysymbnumbrmillion give away pptnumbrxnumbr normal text rate boxnumbr wnumbrtnumbrji',
#   1),
#  ('realli sorri b abl numbr friday hope u find altern hope yr term go ok', 0),
#  ('congratul ore mo owo wa enjoy wish mani happi moment fro wherev go', 0),
#  ('samu shoulder yet', 0),
#  ('time think need know near campu', 0),
#  ('dear matthew plea call numbr landlin complimentari numbr lux tenerif holiday moneysymbnumbr cash await collect ppmnumbr sae cs boxnumbr sknumbrxh',
#   1),
#  ('dun wear jean lor', 0),
#  ('sinc side fever vomitin', 0),
#  ('k k colleg', 0),
#  ('urgent call numbr landlin complimentari numbr tenerif holiday moneysymbnumbr numbr cash await collect sae cs box numbr hpnumbr numbryf numbrppm numbr',
#   1),
#  ('better made friday stuf like pig yesterday feel bleh least writh pain kind bleh',
#   0),
#  ('sell ton coin sell coin someon thru paypal voila money back life pocket',
#   0),
#  ('theyr lot place hospit medic place safe', 0),
#  ('get touch folk wait compani txt back name age opt enjoy commun numbrp sm',
#   1),
#  ('also sorta blown coupl time recent id rather text blue look weed', 0),
#  ('sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expen one',
#   0),
#  ('cant wait see photo use', 0),
#  ('ur cash balanc current numbr pound maxim ur cash send go numbr numbrp msg cc numbr po box numbr numbr tcr wnumbr',
#   1),
#  ('hey book kb sat alreadi lesson go ah keep sat night free need meet confirm lodg',
#   0),
#  ('chk ur belovd ms dict', 0),
#  ('time want come', 0),
#  ('awesom lemm know whenev around', 0),
#  ('shb b ok lor thanx', 0),
#  ('beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#   0),
#  ('also rememb get dobbi bowl car', 0),
#  ('filthi stori girl wait', 1),
#  ('sorri c ur msg yar lor poor thing numbr one night tmr u brand new room numbr sleep',
#   0),
#  ('love deci feel could decid love life would much simpler less magic', 0),
#  ('welp appar retir', 0),
#  ('sort code acc bank natwest repli confirm sent right person', 0),
#  ('', 0),
#  ('u sure u take sick time', 0),
#  ('urgent tri contact u today draw show moneysymbnumbr prize guarant call numbr land line claim mnumbr validnumbrhr',
#   1),
#  ('watch cartoon listen music amp eve go templ amp church u', 0),
#  ('yo chad gymnast class wanna take site say christian class full', 0),
#  ('much buzi', 0),
#  ('better still catch let ask sell lt gt', 0),
#  ('sure night menu know noon menu', 0),
#  ('u want come back beauti necklac token heart give wife like see one give dont call wait till come',
#   0),
#  ('go aptitud class', 0),
#  ('wont b numbr tri numbr sort hou ok', 0),
#  ('yar lor wan numbr go c hor race today mah eat earlier lor ate chicken rice u',
#   0),
#  ('haha awesom omw back', 0),
#  ('yup thk e shop close lor', 0),
#  ('account number', 0),
#  ('eh u send wrongli lar', 0),
#  ('hey ad crap nite borin without ya numbr boggi u bore biatch thanx u wait til nxt time il ave ya',
#   0),
#  ('ok shall talk', 0),
#  ('dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#   0),
#  ('hey pay salari de lt gt', 0),
#  ('anoth month need chocol weed alcohol', 0),
#  ('start search get job day great potenti talent', 0),
#  ('reckon need town eightish walk carpark', 0),
#  ('congrat numbr mobil numbrg videophon r call numbr videochat wid mate play java game dload polyph music nolin rentl',
#   1),
#  ('look fuckin time fuck think', 0),
#  ('yo guess drop', 0),
#  ('carlo say mu lt gt minut', 0),
#  ('offic call lt gt min', 0),
#  ('geeee miss alreadi know think fuck wait till next year togeth love kiss',
#   0),
#  ('yun ah ubi one say ü wan call tomorrow call numbr look iren ere got busnumbr numbr numbr numbr numbr numbr ubi cre ubi tech park numbrph numbrst numbrwkg day èn',
#   0),
#  ('ugh gotta drive back sd la butt sore', 0),
#  ('numbrth juli', 0),
#  ('hi im relax time ever get numbram everi day parti good night get home tomorrow numbrish',
#   0),
#  ('ü ü wan come come lor din c stripe skirt', 0),
#  ('xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish u merri xma',
#   0),
#  ('number', 0),
#  ('chang e one next escal', 0),
#  ('yetund class run water make ok pl', 0),
#  ('lot happen feel quiet beth aunt charli work lot helen mo', 0),
#  ('ü wait numbr bu stop aft ur lect lar dun c ü go get car come back n pick ü',
#   0),
#  ...]

# %%
# define a seed for reproducibility
seed = 1
np.random.seed = seed

# %%
np.random.shuffle(mapped)
list(mapped)
# Out:
# [('much eighth', 0),
#  ('nervou lt gt', 0),
#  ('seriou tell exact word right', 0),
#  ('get numbr lion england tone repli lionm numbr mono lionp numbr poli numbr go numbr www rington co uk origin n best tone numbrgbp network oper rate appli',
#   1),
#  ('call numbr listen extrem dirti live chat go offic right total privaci one know sic listen numbrp min numbr numbrmp numbr',
#   1),
#  ('tonight mate catch sleep new number way', 0),
#  ('sorri call later', 0),
#  ('petey boy wherear friendsar thekingshead come canlov nic', 0),
#  ('badrith chennai sure pick us competit', 0),
#  ('mani happi return day wish happi birthday', 0),
#  ('kaiez enjoy ur tuition gee thk e second option sound beta go yan jiu den msg u',
#   0),
#  ('movi call numbr wat', 0),
#  ('tag friend seem count friend', 0),
#  ('ye nigh cant aha', 0),
#  ('hi im relax time ever get numbram everi day parti good night get home tomorrow numbrish',
#   0),
#  ('ok lor u wan go look numbr u', 0),
#  ('ask call ok', 0),
#  ('head straight', 0),
#  ('r u cook dinner', 0),
#  ('late', 0),
#  ('k might come tonight class let earli', 0),
#  ('oh realli make air talent', 0),
#  ('ha ha pop loo hello ed hello', 0),
#  ('help propo go back tomorrow', 0),
#  ('pl speak wont ask anyth friendship', 0),
#  ('u reckon need numbr arrang transport u thank', 0),
#  ('aight lemm know', 0),
#  ('r ü go send', 0),
#  ('alreadi back home probabl', 0),
#  ('staff name take class us', 0),
#  ('time thinkin goin', 0),
#  ('wait still clear sure sarcast x want live us', 0),
#  ('smile pleasur smile pain smile troubl pour like rain smile sumnumbr hurt u smile becoz someon still love see u smile',
#   0),
#  ('good weekend', 0),
#  ('oh ic thought meant mari jane', 0),
#  ('ok chine food way get fat pay lipo', 0),
#  ('call time job today ok umma ask speed', 0),
#  ('super msg da nalla time', 0),
#  ('send text skype later', 0),
#  ('wont touch permiss', 0),
#  ('tri contact repli offer video phone numbr anytim network min half price line rental camcord repli call numbr',
#   1),
#  ('eh den sat u book e kb liao huh', 0),
#  ('dad get back', 0),
#  ('ok prob', 0),
#  ('thk ü gotta go home urself co b go shop numbr fren present', 0),
#  ('tell friend come round til like lt gt ish', 0),
#  ('u konw waht rael friendship im gving yuo exmpel jsut ese tih msg evrey splle tih msg wrnog bt sitll yuo ra wihtuot ayn mitsak goodnight amp nice sleep sweet dream',
#   0),
#  ('peopl see msg think iam addict msging wrong bcoz know iam addict sweet friend bslvyl',
#   0),
#  ('much pay suganya', 0),
#  ('good afternoon love good see word ym get tm smart move slave smile drink coff await',
#   0),
#  ('probabl money worri thing come due sever outstand invoic work two three month ago',
#   0),
#  ('hiya u pay money account thank got pleasant surpri check balanc u c get statement numbr acc',
#   0),
#  ('yo jp hungri like mofo', 0),
#  ('ur pin', 0),
#  ('seriou spell name', 0),
#  ('raji pl favour pl convey birthday wish nimya pl today birthday', 0),
#  ('email yifeng part oredi ü get fr', 0),
#  ('send logo numbr ur lover numbr name join heart txt love namenumbr namenumbr mobno eg love adam eve numbr numbr yahoo poboxnumbrwnumbrwq txtno numbr ad numbrp',
#   1),
#  ('think wait bu inform get ever get', 0),
#  ('ok give numbr minut think see btw alibi cut hair whole time', 0),
#  ('know god creat gap finger one made come amp fill gap hold hand love', 0),
#  ('alway celebr ny famili', 0),
#  ('umma life vava umma love lot dear', 0),
#  ('plea reserv ticket saturday eve chennai thirunelvali tirunelvali chennai sunday eve alreadi see net ticket avail want book ticket tackl',
#   0),
#  ('lot happen feel quiet beth aunt charli work lot helen mo', 0),
#  ('dun believ u thk u told', 0),
#  ('oh mr sheffield wanna play game okay boss nanni give rai give one', 0),
#  ('eastend tv quiz flower dot compar violet e tulip f lili txt e f numbr numbr chanc numbr win moneysymbnumbr cash wkent numbrpnumbr',
#   1),
#  ('money issu weigh thank breath easier make sure dont regret thank', 0),
#  ('u look numbr da lib got stuff havent finish yet', 0),
#  ('great hear settl well happenin wit ola', 0),
#  ('nope watch tv home go v bore', 0),
#  ('dont think need yellow card uk travel ask someon gone lt gt buck', 0),
#  ('hahaha use brain dear', 0),
#  ('much dirti fellow', 0),
#  ('wannumbr win meet greet westlif numbr u mnumbr current tour numbr unbreak numbr untam numbr unkempt text numbr numbr numbr numbr cost numbrp std text',
#   1),
#  ('still tonight', 0),
#  ('let know got money carlo make call', 0),
#  ('haha good hear offici paid market numbrth', 0),
#  ('urgent ur award complimentari trip eurodisinc trav aco entrynumbr moneysymbnumbr claim txt di numbr numbr numbr moneysymbnumbr morefrmmob shracomorsglsuplt numbr lsnumbr numbraj',
#   1),
#  ('free call pa', 0),
#  ('think da wil', 0),
#  ('urgent plea call numbr landlin abta complimentari numbr tenerif holiday moneysymbnumbr cash await collect sae cs box numbr cwnumbrwx numbrppm',
#   1),
#  ('gonna ask lol think numbr', 0),
#  ('ok come home', 0),
#  ('ok omw castor', 0),
#  ('sarcasm nt scarcasim', 0),
#  ('none happen til get though', 0),
#  ('doesnt need test', 0),
#  ('somewh beneath pale moon light someon think u dream come true goodnit amp sweet dream',
#   0),
#  ('sorri got thing may pub later', 0),
#  ('save money wed lingeri www bridal petticoatdream co uk choo superb select nation deliveri brought weddingfriend',
#   1),
#  ('pl help tell sura expect batteri hont pl send messag download movi thank',
#   0),
#  ('fuck babe miss alreadi know let send money toward net need want crave', 0),
#  ('hi babe im home wanna someth xx', 0),
#  ('alrit girl u know gail neva wrong take care sweet worri c u lnumbrtr hun love yaxxx',
#   0),
#  ('cool like swim pool jacuzzi hou', 0),
#  ('great trip india bring light everyon project everyon lucki see smile bye abiola',
#   0),
#  ('news hassl get weed week andr money haughaighgtujhyguj', 0),
#  ('charg transfer charg withdraw anyhow like', 0),
#  ('urgent mobil award moneysymbnumbr bonu caller prize numbr numbr numbr final tri contact u call landlin numbr boxnumbrwrnumbrc numbrppm',
#   1),
#  ('pick rayan macleran', 0),
#  ('wnt buy bmw car urgent vri urgent hv shortag lt gt lac sourc arng di amt lt gt lac prob',
#   0),
#  ('ladi first genu second k', 0),
#  ('hi numbr ibh custom loyalti offer new nokianumbr mobil moneysymbnumbr txtauction txt word start numbr get numbrt',
#   1),
#  ('ill numbr min look', 0),
#  ('promi take good care princess run plea send pic get chanc ttyl', 0),
#  ('fwiw reason around time smoke ga afford around someon tell appar happen somebodi want light',
#   0),
#  ('help u swoop pick u wherev ur bird r meet u want', 0),
#  ('home', 0),
#  ('hello per request lt gt rs numbr transfer', 0),
#  ('didnt get anyth da', 0),
#  ('still play gautham', 0),
#  ('wa ur openin sentenc formal anyway fine juz tt eatin much n puttin weight haha anythin special happen',
#   0),
#  ('rct thnq adrian u text rgd vatian', 1),
#  ('shame mayb cld meet hr tomo', 0),
#  ('hellogorg u fone charg lst nitw wen u texd hopeu ad nice wkend im sure u lookin numbrward numbr c u numbrmrw luv jaz',
#   0),
#  ('mayb fat finger press button know', 0),
#  ('ye realli great bhaji told kalli best cricket sachin world tough get', 0),
#  ('noth ok anyway give treat', 0),
#  ('love brother time talk english grin say hey muhommad penni say hello across sea',
#   0),
#  ('six chanc win cash numbr numbr numbr pound txt cshnumbr send numbr cost numbrp day numbrday numbr tsandc appli repli hl numbr info',
#   1),
#  ('dun cut short leh u dun like ah fail quit sad', 0),
#  ('babe hope ok shit night sleep fell asleep numbr knacker dread work tonight thou upto tonight x',
#   0),
#  ('lol would awesom payback', 0),
#  ('get threat sale execut shifad rai complaint offici messag', 0),
#  ('grnumbr new servic live sex video chat mob see sexiest dirtiest girl live ur phone numbr detail text horni numbr cancel send stop numbr',
#   1),
#  ('ü wan numbr meet n combin part da rest da project go', 0),
#  ('text way cup stop work bu', 0),
#  ('whatsup dont u want sleep', 0),
#  ('oki', 0),
#  ('sexi sexi cum text im wet warm readi porn u fun msg free recd msg numbrp inc vat numbr cancel text stop',
#   1),
#  ('yar lor wan numbr go c hor race today mah eat earlier lor ate chicken rice u',
#   0),
#  ('got take numbr take part wrc ralli oz u lucozad energi text ralli le numbr numbrp see pack lucozad co uk wrc itcould u',
#   1),
#  ('probabl coupl hour top', 0),
#  ('hello u call wen u finish wrk fanci meetin wiv u tonit need break dabook numbr hr last nite numbr today wrk',
#   0),
#  ('cab avail pick drop door step', 0),
#  ('ugh leg hurt musta overdid mon', 0),
#  ('misplac number send text old number wonder heard year best mcat got number atlanta friend',
#   0),
#  ('sorri call later', 0),
#  ('dude got haircut breezi', 0),
#  ('camera award sipix digit camera call numbr fromm landlin deliveri within numbr day',
#   1),
#  ('hi mandi sullivan call hotmix fm chosen receiv moneysymbnumbr easter prize draw plea telephon numbr claim numbr numbr numbr prize transfer someon el',
#   1),
#  ('uncl atlanta wish guy great semest', 0),
#  ('numbr new messag plea call numbr', 1),
#  ('get headach tri figur u trust math promi', 0),
#  ('ok ok take care understand', 0),
#  ('peopl game mall iouri kaila', 0),
#  ('hello news job make wait fifth week yeah im woozl weasel exet still home numbr',
#   0),
#  ('aathi dear', 0),
#  ('yeah confirm stay weekend', 0),
#  ('bloodi hell cant believ forgot surnam mr ill give u clue spanish begin', 0),
#  ('congrat numbr mobil numbrg videophon r call numbr videochat wid ur mate play java game dload polyh music nolin rentl bxnumbr ipnumbr numbrw numbrpm',
#   1),
#  ('know mood today', 0),
#  ('good morn dear shijutta great amp success day', 0),
#  ('pl dont restrict eat anythin like next two day', 0),
#  ('sorri batteri die yeah', 0),
#  ('hiya comin numbr bristol numbr st week april le got rudi new yr eve snore drunk u bak colleg yet work send ink numbr bath',
#   0),
#  ('stand away heart ach without wonder crave', 0),
#  ('good morn princess happi new year', 0),
#  ('amaz quot sometim life difficult decid wrong lie bring smile truth bring tear',
#   0),
#  ('urgent mobil number award moneysymbnumbr prize guarant call numbr land line claim numbr valid numbrhr',
#   1),
#  ('today song dedic day song u dedic send ur valuabl frnd first rpli', 0),
#  ('ahhhh woken bad dream u tho dont like u right didnt know anyth comedi night guess im',
#   0),
#  ('hey glad u r better hear u treat urself digi cam good r numbrpm fab new year c u coupla wk',
#   0),
#  ('sell ton coin sell coin someon thru paypal voila money back life pocket',
#   0),
#  ('singl line big mean miss anyth numbr ur best life miss ur best life anyth gud nyt',
#   0),
#  ('fret buy ovul test strip send wont get til like march send postal address u alright okay',
#   0),
#  ('tell pl', 0),
#  ('ugh u apolog admit u wrong ask take u back', 0),
#  ('cant talk call dont keep call', 0),
#  ('u lost ill alway b numbru intend numbr hurt u never knew u felt iwa marin itriednumbrtel urmom careabout u',
#   0),
#  ('yo way could pick someth tonight', 0),
#  ('oooh got plenti', 0),
#  ('numbr polyphon tone numbr ur mob everi week txt ptnumbr numbr numbrst tone free get txtin tell ur friend numbrp tone numbr repli hl numbrinfo',
#   1),
#  ('pl full name joke school co fee univ florida seem actual lt gt k pl holla back',
#   0),
#  ('let know chang next numbrhr even appendix age rang howev imposs chill let know numbrhr',
#   0),
#  ('nope juz work', 0),
#  ('guy kadeem sell sinc break know one guy paranoid fuck like sell without til late tonight',
#   0),
#  ('err cud go numbrpm got way contact', 0),
#  ('k call ah', 0),
#  ('free numbrst week entri numbr textpod numbr chanc numbr win numbrgb ipod moneysymbnumbr cash everi wk txt pod numbr ts cs www textpod net custcar numbr',
#   1),
#  ('haha awesom omw back', 0),
#  ('watch hou entertain get whole hugh lauri thing even stick ind especi stick',
#   0),
#  ('know complain num bettr directli go bsnl offc nd appli', 0),
#  ('oh numbr outsid player allow play know', 0),
#  ('numbr guarant latest nokia phone numbrgb ipod mpnumbr player moneysymbnumbr prize txt word collect numbr tc llc ny usa numbrp mt msgrcvdnumbr',
#   1),
#  ('yup lunch buffet u eat alreadi', 0),
#  ('sir good morn hope good weekend call let know abl rai lt gt dad howev said would make rest avail mid feb amount still quit short hope would help good day abiola',
#   0),
#  ('good day', 0),
#  ('competit', 0),
#  ('shower babi', 0),
#  ('yeah usual guy town definit peopl around know', 0),
#  ('yet chikku wat abt u', 0),
#  ('lt gt buck bank fee fix better call bank find', 0),
#  ('dude avatar numbrd imp one point thought actual fli room almost tri hittng one reflex',
#   0),
#  ('tel softwar name', 0),
#  ('cme want go ho numbrmorow wil cme got dear didnt say time', 0),
#  ('much gave morn', 0),
#  ('cook rather nice salmon la', 0),
#  ('someon u know ask date servic numbr contact cant guess call numbr reveal pobox numbr snumbrxi numbrp',
#   1),
#  ('dont know get messag', 0),
#  ('wait e car numbr mum lor u leh reach home alreadi', 0),
#  ('er hello thing quit go plan limp slowli home follow aa exhaust hang', 0),
#  ('free top rington sub weekli rington get numbrst week free send subpoli numbr numbr per week stop sm numbr',
#   1),
#  ('new theori argument win situat lose person dont argu ur friend kick amp say alway correct',
#   0),
#  ('usf guess might well take numbr car', 0),
#  ('tuesday night r u numbr real', 0),
#  ('time come', 0),
#  ('womdar actor', 0),
#  ('mind ask happen dont say uncomfort', 0),
#  ('select stay numbr numbr top british hotel noth holiday worth moneysymbnumbr claim call london numbr bx numbr swnumbrss',
#   1),
#  ('norm tomorrow finish numbr co st test need sort librari stuff point tomo got letter today access til end march better get move',
#   0),
#  ('k k advanc happi pongal', 0),
#  ('numbrp numbr alfi moon children need song ur mob tell ur mnumbr txt tone chariti numbr nokia poli chariti poli zed numbr profit numbr chariti',
#   1),
#  ('tri contact offer new video phone numbr anytim network min half price rental camcord call numbr repli deliveri wed',
#   1),
#  ('thinkin someon good drug', 0),
#  ('twink bear scalli skin jock call miss weekend fun call numbr numbrp min numbr stop text call numbr nat rate',
#   1),
#  ('alway say welp', 0),
#  ('fuck babe happen come never came back', 0),
#  ('dude ive see lotta corvett late', 0),
#  ('lol could starv lose pound end day', 0),
#  ('special select receiv numbr pound award call numbr line close cost numbrppm numbr cs appli ag promo',
#   1),
#  ('sorri pain ok meet anoth night spent late afternoon casualti mean done stuffnumbrmoro includ time sheet sorri',
#   0),
#  ('complet degr use join financ', 0),
#  ('take care n get well soon', 0),
#  ('also piec', 0),
#  ('sorri cant take call right happen r numbrwaxsto wat want come ill get medic insur abl deliv basic care current shop right medic insur give til friday morn see major person guid right insur',
#   0),
#  ('place ur point e cultur modul alreadi', 0),
#  ('ok gonna head usf like fifteen minut', 0),
#  ('watch movi alreadi xy want numbr shop shop w', 0),
#  ('take care financ problem help', 0),
#  ('boy love gal propsd bt didnt mind gv lv lttr bt frnd threw thm boy decid numbr aproach gal dt time truck speed toward gal wn numbr hit girl boy ran like hell n save ask hw cn u run fast boy repli boost secret energi n instantli girl shout energi n thi live happili numbrgthr drink boost evrydi moral stori hv free msg gud ninumbr',
#   0),
#  ('mayb find someth el instead', 0),
#  ('would u fuckin believ didnt know thur pre book cancel need b sack', 0),
#  ('see finish load loan pay', 0),
#  ('hai dear friend new amp present number rajitha raj ranju', 0),
#  ('ha us e thing got tv numbr watch u thk numbr go tonight u alreadi haf smth mind',
#   0),
#  ('minimum walk numbrmil day', 0),
#  ('alway chat fact need money rai', 0),
#  ('hello lover goe new job happi think wake slave send tea kiss across sea',
#   0),
#  ('k k cant come search job', 0),
#  ('ok askd u knw tht', 0),
#  ('tell someth okay', 0),
#  ('money numbr steve mate', 0),
#  ('hot n horni live local text repli hear strt back numbrp per msg netcollex ltdhelpdesk numbr repli stop end',
#   1),
#  ('shall come get pickl', 0),
#  ('numbr new voicemail plea call numbr', 1),
#  ('orang bring rington time chart hero free hit week go rington pic wap stop receiv tip repli stop',
#   1),
#  ('u gonna get deu ex', 0),
#  ('well know mean text', 0),
#  ('oh forward messag thought send', 0),
#  ('u wana see', 0),
#  ('ye start send request make pain came back back bed doubl coin factori gotta cash nitro',
#   0),
#  ('somewh fredericksburg', 0),
#  ('know dat feelin pete wuld get em nuther place nuther time mayb', 0),
#  ('yeah imagin would realli gentl unlik doc treat patient like turkey', 0),
#  ('sday join train start today', 0),
#  ('perform award calcul everi two month current one month period', 0),
#  ('one day crab run sea shore wave came n clear footprint crab crab ask frnd r u clear beauti footprint wave repli fox follow ur footprint catch clear frndsship never let u dwn gud nyt',
#   0),
#  ('wyli tampa sarasota', 0),
#  ('ye fine love safe', 0),
#  ('sorri vikki watch olav mandara movi kano trishul theatr wit frnd', 0),
#  ('audri lousi autocorrect', 0),
#  ('quit late lar ard numbr anyway wun b drivin', 0),
#  ('emigr someth ok mayb numbr bit hope', 0),
#  ('shit surpri went spent even french guy met town fool around bit let fuck',
#   0),
#  ('oga left phone home saw ur messag hope good great weekend', 0),
#  ('motiv behind everi dark shine light wait find behind everi best friend alway trust love bslvyl',
#   0),
#  ('numbr numbram numbrpm cost numbrp', 1),
#  ('oh come ah', 0),
#  ('hmv bonu special numbr pound genuin hmv voucher answer numbr easi question play send hmv numbr info www numbrperc real com',
#   1),
#  ('k head min see', 0),
#  ('numbrp numbr alfi moon children need song ur mob tell ur mnumbr txt tone chariti numbr nokia poli chariti poli zed numbr profit numbr chariti',
#   1),
#  ('aiyar dun disturb u liao thk u lot numbr aft ur cupboard come', 0),
#  ('hey forget mine possess properti mmm childish smile', 0),
#  ('u hide stranger', 0),
#  ('gudnit tc practic go', 0),
#  ('numbr new voicemail plea call numbr', 1),
#  ('cant pick phone right pl send messag', 0),
#  ('ok', 0),
#  ('yeah think usual guy still pass last night get ahold anybodi let know throw',
#   0),
#  ('current scotland', 0),
#  ('doesnt make sen take unless free need know wikipedia com', 0),
#  ('wat r u', 0),
#  ('dear u invit xchat final attempt contact u txt chat numbr numbrp msgrcvdhg suitenumbr numbrland row wnumbrjnumbrhl ldn numbr yr',
#   1),
#  ('privat numbr account statement show numbr un redeem point call numbr identifi code numbrxxnumbr expir numbr numbr numbr',
#   1),
#  ('thank rington order refer tnumbr charg gbp numbr per week unsubscrib anytim call custom servic numbr',
#   1),
#  ('scotland hope show jjc tendenc take care live dream', 0),
#  ('want ask ü wait numbr finish lect co lect finish hour anyway', 0),
#  ('beauti truth graviti read care heart feel light someon feel heavi someon leav goodmorn',
#   0),
#  ('congrat nokia numbr video camera phone call numbr call cost numbrppm ave call numbrmin vari mobil numbr close numbr post bcmnumbr ldn wcnumbrnnumbrxx',
#   1),
#  ('oic co n si got lunch today dad went dunno whether numbr eat sch wat', 0),
#  ('u dun drive go numbr sch', 0),
#  ('stop club tone repli stop mix see tone com enjoy html term club tone cost gbpnumbr week mfl po box numbr mknumbr numbrwt numbr numbr',
#   1),
#  ('want grasp pretti booti', 0),
#  ('got back dislik bed', 0),
#  ('usual take fifteen fuck minut respond ye question', 0),
#  ('urgent call numbr landlin complimentari numbr tenerif holiday moneysymbnumbr numbr cash await collect sae cs box numbr hpnumbr numbryf numbrppm numbr',
#   1),
#  ('realli dude friend afraid', 0),
#  ('weightloss girl friend make load money ebay someth give thank god', 0),
#  ('geeeee love much bare stand', 0),
#  ('need ke qi ü bore izzit suddenli thk', 0),
#  ('ok right later', 0),
#  ('seen facebook huh lol', 0),
#  ('prabha soryda reali frm heart sori', 0),
#  ('hi yiju meet u numbr tmr', 0),
#  ('want lick pussi', 0),
#  ('freemsg numbr month unlimit free call activ smartcal txt call numbr subscriptnnumbrgbp wk unlimit call help numbr stop txt stop landlineonli',
#   1),
#  ('reach ur home lt gt minut', 0),
#  ('aight call close', 0),
#  ('right make appoint right', 0),
#  ('plz tell bslvyl sent via fullonsm com', 0),
#  ('speak feel word better silenc gud mrng', 0),
#  ('lt gt min stop somewh first', 0),
#  ('today accept day u accept brother sister lover dearnumbr bestnumbr closnumbr lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#   0),
#  ('free numbrst week nonumbr nokia tone numbr ur mob everi week txt nokia numbr get txting tell ur mate zed pobox numbr wnumbrwq normnumbrp tone numbr',
#   1),
#  ('issu right ill fix tomorrow', 0),
#  ('hi harish rent transfr ur acnt', 0),
#  ('ok juz receiv', 0),
#  ('kalli dismissi numbrnd test', 0),
#  ('carri disturb', 0),
#  ('valu custom plea advi follow recent review mob award moneysymbnumbr bonu prize call numbr',
#   1),
#  ('laid airtel line rest', 0),
#  ('pick numbrpm go taunton still want come', 0),
#  ('decemb mobil numbrmth entitl updat latest colour camera mobil free call mobil updat co free numbr',
#   1),
#  ('want talk', 0),
#  ('urgent plea call numbr landlin moneysymbnumbr cash numbr holiday await collect cs sae po box numbr mnumbrxi numbr',
#   1),
#  ('dear voucher holder numbr claim numbrst class airport loung pass use holiday voucher call numbr book quot numbrst class x numbr',
#   1),
#  ('thank vote sing along star karaok mobil free link repli sing', 1),
#  ('sorri sent blank msg yup tri numbr seriou studi', 0),
#  ('plea call numbr immedi urgent messag wait', 1),
#  ('donno scorabl', 0),
#  ('pl come quick cant bare', 0),
#  ('need detail onlin job', 0),
#  ('carlo say mu lt gt minut', 0),
#  ('network job', 0),
#  ('love one law make happi person love way friendship one law never make ur friend feel alon aliv gud night',
#   0),
#  ('well offici philosoph hole u wanna call home readi save', 0),
#  ('ill b soon', 0),
#  ('near kalainar tv offic thenampet', 0),
#  ('alright tyler got minor crisi home sooner thought asap', 0),
#  ('use foreign stamp whatev send', 0),
#  ('im done studyn librari', 0),
#  ('ju finish watch tv u', 0),
#  ('ur go numbr bahama callfreefon numbr speak live oper claim either bahama crui ofmoneysymbnumbr cash numbr opt txt x numbr',
#   1),
#  ('boy sweet word left morn sigh goe day love start studi', 0),
#  ('ok bag', 0),
#  ('u make fb list', 0),
#  ('lol oh got friend dog', 0),
#  ('u definit need modul e human di sem izzit u wan numbr take modul numbrst',
#   0),
#  ('lol know hey someon great inperson flea forum love', 0),
#  ('mani thing antibiot use chest abdomen gyna infect even bone infect', 0),
#  ('whore unbeliev', 0),
#  ('anyway seriou hit back otherwi light armand alway shit vomit', 0),
#  ('dear reliev westonzoyland go plan end', 0),
#  ('sindu got job birla soft', 0),
#  ('k k special today', 0),
#  ('hey someth came last min think wun sign tmr hee', 0),
#  ('babe u want dont u babi im nasti thing numbr filthyguy fanci rude time sexi bitch go slo n hard txt xxx slo numbrmsg',
#   1),
#  ('go wipro interview today', 0),
#  ('imagin life without see fast u search worri l alway disturb u goodnoon', 0),
#  ('surf onlin store offer want buy thing', 0),
#  ('aiyah wait lor u entertain hee', 0),
#  ('dunno lei thk mum lazi go neva ask yet', 0),
#  ('go numbr orchard lareadi reach soon u reach', 0),
#  ('merri christma babe love ya kiss', 0),
#  ('hey hey wereth monkeespeopl say monkeyaround howdi gorgeou howu doin foundurself jobyet sausag love jen xxx',
#   0),
#  ('fuuuuck need stop sleepin sup', 0),
#  ('dint tell anyth angri told abi', 0),
#  ('gokila talk aha', 0),
#  ('din tell u ju numbr', 0),
#  ('superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#   0),
#  ('lt gt ish minut numbr minut ago wtf', 0),
#  ('ok', 0),
#  ('nutter cutter ctter cttergg cttargg ctargg ctagg ie', 0),
#  ('bugi oso near wat', 0),
#  ('come aliv better correct good look figur', 0),
#  ('heart empti without love mind empti without wisdom eye r empti without dream amp life empti without frnd alwi touch good night amp sweet dream',
#   0),
#  ('know peopl still town', 0),
#  ('regist subscrib yr draw numbr moneysymbnumbr gift voucher b enter receipt correct next olymp txt numbr',
#   1),
#  ('drop em omw back', 0),
#  ('call u done', 0),
#  ('get back home', 0),
#  ('ur paper', 0),
#  ('yup ok', 0),
#  ('happi sad one thing past good morn', 0),
#  ('late call tomorrow morn take care sweet dream u ummifi bye', 0),
#  ('ill call u numbrmrw ninish address icki american freek wont stop callin numbr bad jen k eh',
#   0),
#  ('pathaya enketa maraikara pa', 0),
#  ('slept thinkthi time lt gt pm danger', 0),
#  ('sunshin quiz win super soni dvd record cannam capit australia text mquiz numbr b',
#   1),
#  ('good even sir al salam wahleykkum share happi news grace god got offer tayseer tissco join hope fine inshah allah meet sometim rakhesh visitor india',
#   0),
#  ('messag great doctor india numbr drink appi fizz contain cancer cau age', 0),
#  ('per request mell mell oru minnaminungint nurungu vettam set callertun caller press numbr copi friend callertun',
#   0),
#  ('okay lor wah like def wont let us go haha say term condit', 0),
#  ('look', 0),
#  ('ok', 0),
#  ('detroit home snow enjoy', 0),
#  ('free numbrst week entri numbr textpod numbr chanc numbr win numbrgb ipod moneysymbnumbr cash everi wk txt vpod numbr ts cs www textpod net custcar numbr',
#   1),
#  ('work plea call', 0),
#  ('fine way u feel way gota b', 0),
#  ('cheer u tex mecau u werebor yeah okden hunni r uin wk sat sound likeyour havin grnumbrfun j keep updat countinlot lovem xxxxx',
#   0),
#  ('much would cost hire hitman', 0),
#  ('garag key bookshelf', 0),
#  ('messag responc happend', 0),
#  ('u secret admir reveal think u r special call numbr opt repli reveal stop numbr per msg recd cust care numbr',
#   1),
#  ('movi laptop', 0),
#  ('gotta collect da car numbr lei', 0),
#  ('xam hall boy ask girl tell start term di answer den manag lot hesit n lookin around silent said intha ponnung ipaditan',
#   0),
#  ('stop old man get build snowman snow angel snowbal fight', 0),
#  ('stayin troubl stranger saw dave day sort still bloke u gona get girl mr ur mum still think get numbrgetha',
#   0),
#  ('say lt gt year old man money last lt gt still wait check', 0),
#  ('é moneysymbnumbr ard é rest ard moneysymbnumbr least é price numbr é numbr bedrm moneysymbnumbr',
#   0),
#  ('hi neva worri bout da truth coz truth lead numbr ur heart least uniqu person like u deserv sleep tight morn',
#   0),
#  ('yup wun believ wat u realli neva c e msg sent shuhui', 0),
#  ('cant pick phone right pl send messag', 0),
#  ('wow love sooo much know bare stand wonder day goe well love think miss', 0),
#  ('kalli wont play first two odi', 0),
#  ('pl speak custom machan', 0),
#  ('yet like keep touch easiest way barcelona way ru hou', 0),
#  ('friendship game play word say start march end may tomorrow yesterday today e',
#   0),
#  ('okay wait ah', 0),
#  ('dear u invit xchat final attempt contact u txt chat numbr', 1),
#  ('thank keep mind', 0),
#  ('yup song bro creativ neva test qualiti said check review onlin', 0),
#  ('numbr sleep bag numbr blanket paper phone detail anyth el', 0),
#  ('u got person stori', 0),
#  ('hey thk juz go accordin wat discuss yest lor except kb sun co nt much lesson go attend kb sat',
#   0),
#  ('mum sent mani mani messag sinc got want know actual get enjoy rest day', 0),
#  ('yep pretti sculptur', 0),
#  ('sad stori man last week b day wife nt wish parent forgot n kid went work even colleagu wish',
#   0),
#  ('hi engag fixd lt gt th next month know realli shock bt hmm njan vilikkam ws al sudn',
#   0),
#  ('univ southern california', 0),
#  ('sent like', 0),
#  ('yup izzit still rain heavili co e mrt c outsid', 0),
#  ('love night xxx', 0),
#  ('pl accept one day beg chang number', 0),
#  ('hmmm mayb tri e shoppin area one forgot e name hotel', 0),
#  ('ü go buy wif meet ü later', 0),
#  ('free entri numbr wkli comp win fa cup final tkt numbrst may numbr text fa numbr receiv entri question std txt rate c appli numbrovernumbr',
#   1),
#  ('bought test yesterday someth let know exact day u ovul get numbru numbr numbrwk pl pl dont fret know u r worri pl relax also anyth ur past histori u need tell',
#   0),
#  ('numbr latest g still scroung ammo want give new ak tri', 0),
#  ('valu vodafon custom comput pick win moneysymbnumbr prize collect easi call numbr',
#   1),
#  ('go aptitud class', 0),
#  ('god bless get good sleep dear pray', 0),
#  ('opinion numbr numbr jada numbr kusruthi numbr lovabl numbr silent numbr spl charact numbr matur numbr stylish numbr simpl pl repli',
#   0),
#  ('depend u go lor', 0),
#  ('r outsid alreadi', 0),
#  ('edison rightli said fool ask question wise man answer know us speechless viva gm gn ge gnt',
#   0),
#  ('congrat great want tell tell score co might make relax motiv thank share',
#   0),
#  ('match start india lt gt numbr', 0),
#  ('sorri call later meet', 0),
#  ('u see post facebook', 0),
#  ('sorri batteri die come get gram place', 0),
#  ('guai ü shd haf seen naughti ü free today go jog', 0),
#  ('tire slept well past night', 0),
#  ('worri sure get', 0),
#  ('anyth lor', 0),
#  ('cool let know kick around lt gt day', 0),
#  ('spoon okay', 0),
#  ('jordan got vote last nite', 0),
#  ('u think girl propo u today se ur bloodi funki shit fuck face asssssholee',
#   0),
#  ('guy flash go call call madam take care oh', 0),
#  ('dear angri busi dear', 0),
#  ('meet u work tel shall work tomorrow', 0),
#  ('free entri numbr weekli comp chanc win ipod txt pod numbr get entri std txt rate c appli numbr detail numbr',
#   1),
#  ('got salt rub open wound like', 0),
#  ('free numbrst week nonumbr nokia tone numbr ur mob everi week txt nokia numbr get txting tell ur mate www getz co uk pobox numbr wnumbrwq normnumbrp tone numbr',
#   1),
#  ('nite nite pocay wocay luv u n e thing numbreva promi ring u numbrmorrowxxxx',
#   0),
#  ('day work day except saturday sunday', 0),
#  ('ya told ask wat matter', 0),
#  ('love cuddl want hold strong arm right', 0),
#  ('wish famili merri x happi new year advanc', 0),
#  ('unlimit text limit minut', 0),
#  ('ok go sleep hope meet', 0),
#  ('still mayb leav credit card get ga get back like told', 0),
#  ('dunno close oredi ü v fan', 0),
#  ('haha awesom might need take doin tonight', 0),
#  ('k give back thank', 0),
#  ('got outta class gonna go gym', 0),
#  ('today sunday sunday holiday work', 0),
#  ('final readi fyi', 0),
#  ('da vijay go talk jaya tv', 0),
#  ('reach home safe n sound liao', 0),
#  ('hou maid murder coz man murder lt gt th januari public holiday govt instituit close includ post offic',
#   0),
#  ('sorri call later', 0),
#  ('first time histori need comfort luxuri sold price india onion rs lt gt petrol rs lt gt beer rs lt gt shesil lt gt',
#   0),
#  ('ever one foot', 0),
#  ('got look scrumptiou daddi want eat night long', 0),
#  ('valu custom plea advi follow recent review mob award moneysymbnumbr bonu prize call numbr',
#   1),
#  ('gonna ring weekend wot', 0),
#  ('site simul test give tough question test readi', 0),
#  ('final chanc claim ur moneysymbnumbr worth discount voucher today text ye numbr savamob member offer mobil cs savamob poboxnumbr mnumbruz moneysymbnumbr sub numbr',
#   1),
#  ('oop let know roommat done', 0),
#  ('took mr owl numbr lick', 0),
#  ('dude im longer pisc im aquariu', 0),
#  ('even brother like speak treat like aid patent', 0),
#  ('ok go chang also', 0),
#  ('shall come get pickl', 0),
#  ('mm entir sure understood text hey ho weekend', 0),
#  ('bit weird even suppo happen good idea sure pub', 0),
#  ('stupid auto correct phone', 0),
#  ('hope great day', 0),
#  ('wat time ü finish', 0),
#  ('creepi crazi', 0),
#  ('yup', 0),
#  ('think could stop like hour roommat look stock trip', 0),
#  ('bu leav lt gt', 0),
#  ('know jack shit anyth say ask someth help want pretend text whatev respon hypotheticalhuagauahahuagahyuhagga',
#   0),
#  ('reali sorri recogni number confu r u plea', 0),
#  ('fine good hear dear happi new year oh', 0),
#  ('xma new year eve ticket sale club day numbram till numbrpm thur fri sat night week sell fast',
#   1),
#  ('still look car buy gone numbrth drive test yet', 0),
#  ('japan proverb one u none u must indian version one let none leav final kerala version one stop none make strike',
#   0),
#  ('hey sexi bun day word morn ym think', 0),
#  ('ok anoth number', 0),
#  ('sweet heart', 0),
#  ('av new number wil u use one ta', 0),
#  ('onum ela pa normal', 0),
#  ('good afternoon babe goe day job prospect yet miss love sigh', 0),
#  ('ok problem u frm wat matter', 0),
#  ('sound good keep post', 0),
#  ('whenevr ur sad whenevr ur gray remembr im numbr listn numbr watevr u wanna say ju walk wid littl amp promi bring back ur smile',
#   0),
#  ('wish famili merri x happi new year advanc', 0),
#  ('love u numbr littl poci bell sorri love u', 0),
#  ('convey regard', 0),
#  ('sorri flake last night shit seriou goin roommat tonight', 0),
#  ('free msg singl find partner area numbr real peopl wait chat send chat numbrcncl send stopc numbrmoneysymbnumbr per msg',
#   1),
#  ('r mani model soni ericson also der lt gt luk good bt forgot modl', 0),
#  ('seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#   0),
#  ('ela kano il download come wen ur free', 0),
#  ('rememb hurt day satan impost need pay price may destini keep go u said pray get mind get',
#   0),
#  ('plea call custom servic repr freephon numbr numbr numbr numbram numbrpm guarant moneysymbnumbr cash moneysymbnumbr prize',
#   1),
#  ('hack chat get backdoor entri numbr chat room fraction cost repli neonumbr call numbr subscrib numbrp pm dp bcm box numbr ldn wcnumbrnnumbrxx',
#   1),
#  ('oki', 0),
#  ('happen gotten job begun registr perman resid', 0),
#  ('alreadi got flaki parent snot suppo child job support parent ride age anyway suppo support hurt unint hurt nonetheless',
#   0),
#  ('realli need numbr kiss u miss u babi ur babi numbreva', 0),
#  ('fine thank', 0),
#  ('know old dom told yesterday name roger got touch last night want meet today numbr pm',
#   0),
#  ('sorri u unsubscrib yet mob offer packag min term numbr week pl resubmit request expiri repli themob help numbr info',
#   1),
#  ('school n da lab stuff give call ü r done', 0),
#  ('dont search love let love find u call fall love bcoz u dont forc u fall u know smeon hold u bslvyl',
#   0),
#  ('dunno dad said come home numbr bring us numbr lunch yup go w u lor call u reach school lor',
#   0),
#  ('urgent mobil award moneysymbnumbr numbr bonu caller prize numbr numbr numbr final attempt numbr contact u call numbr',
#   1),
#  ('hi shanil rakhesh thank exchang uncut diamond stuff leav back excel servic dino prem',
#   0),
#  ('yo guess drop', 0),
#  ('sorri call later', 0),
#  ('sad stori man last week b day wife nt wish parent forgot n kid went work even colleagu wish',
#   0),
#  ('night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay gud mrng',
#   0),
#  ('dunno let go learn pilat', 0),
#  ('finish liao u', 0),
#  ('fair enough anyth go', 0),
#  ('still game', 0),
#  ('sorri da gone mad mani pend work', 0),
#  ('dad say hurri hell', 0),
#  ('take phone callon friday assum year', 0),
#  ('say hi get ass back south tampa prefer kegger', 0),
#  ('ok problem get taxi c ing tomorrow tuesday tuesday think r go cinema', 0),
#  ('love know feel make belli warm wish love shall meet dream ahmad ador kiss',
#   0),
#  ('go numbr dinner soon', 0),
#  ('boy late numbr home father power frndship', 0),
#  ('hey tmr meet bugi numbr', 0),
#  ('thought could go dinner treat seem ok', 0),
#  ('dunno lei ü decid lor abt leona oop tot ben go n msg', 0),
#  ('today system sh get readi well also deep well', 0),
#  ('mobi pub quiz win moneysymbnumbr high street prize u know new duchess cornwal txt first name numbr unsub stop moneysymbnumbr numbr sp arrow',
#   1),
#  ('want tell bad feel basic time text late need drug', 0),
#  ('work ah den numbr plu lor u workin oso rite den go orchard lor place go liao',
#   0),
#  ('watch telugu movi wat abt u', 0),
#  ('erm woodland avenu somewh get parish magazin telephon number', 0),
#  ('carlo took leav minut', 0),
#  ('id onluy matter get offcampu', 0),
#  ('santa call would littl one like call santa xma eve call numbr book time',
#   1),
#  ('much fight good nite', 0),
#  ('call get chanc plz lt numbr', 0),
#  ('dont file bag work call tell find anyth room', 0),
#  ('yo im right yo work', 0),
#  ('mayb say hi find got card great escap wetherspoon', 0),
#  ('dunno lei shd b drive lor co go sch numbr hr oni', 0),
#  ('today song dedic day song u dedic send ur valuabl frnd first rpli', 0),
#  ('ju chillaxin', 0),
#  ('posibl dnt live lt gt centuri cm frwd n thnk differ', 0),
#  ('happi valentin day know earli hundr handsom beauti wish thought finish aunti uncl numbrst',
#   0),
#  ('er yeah b numbr numbr sorri tell pub cafe sit come wen u', 0),
#  ('hi darlin im way london smash anoth driver big dent im realli miss u u xxx',
#   0),
#  ('height confid aeronaut professor wer calld amp wer askd numbr sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt numbr didnt move said made student wont even start datz confid',
#   0),
#  ('well lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#   0),
#  ('numbr night nt stay port step liao ex', 0),
#  ('urgent numbr week free membership moneysymbnumbr numbr prize jackpot txt word claim numbr c www dbuk net lccltd pobox numbrldnwnumbranumbrrwnumbr',
#   1),
#  ('sorri miss babe late slept hope enjoy drive lesson boytoy miss tea kiss',
#   0),
#  ('spare power suppli', 0),
#  ('ok problem yup go sch numbr rem correctli', 0),
#  ('uncl atlanta wish guy great semest', 0),
#  ('want funk ur fone weekli new tone repli tonesnumbru numbr text www rington co uk origin n best tone numbrgbp network oper rate appli',
#   1),
#  ('fine rememb', 0),
#  ('ta daaaaa home babe still', 0),
#  ('meet da call', 0),
#  ('hou maid murder coz man murder lt gt th januari public holiday govt instituit close includ post offic understand',
#   0),
#  ('complimentari numbr star ibiza holiday moneysymbnumbr numbr cash need urgent collect numbr landlin lose boxnumbrsknumbrwpnumbrppmnumbr',
#   1),
#  ('new local date area lot new peopl regist area repli date start numbr www flirtparti us replysnumbr',
#   1),
#  ('urgent mobil award moneysymbnumbr numbr bonu caller prize numbr numbr numbr numbrnd attempt contact call numbr numbr numbr boxnumbrqu bt nation rate',
#   1),
#  ('bring got', 0),
#  ('oh ye speak txt numbr u hmm u get email', 0),
#  ('god pick flower dippeditinadew lovingli touch itwhichturnedinto u gift tomeandsaid friend numbru',
#   0),
#  ('promi though even gotten dinner yet', 0),
#  ('numbrappl day doctor numbrtulsi leaf day cancer numbrlemon day fat numbrcup milk day bone problm numbr litr watr day disea snd th numbr u care',
#   0),
#  ('yeah got one line us', 0),
#  ('btw regard realli tri see anyon el numbrth guy commit random dude', 0),
#  ('wud never mind u dont miss u dont need u wil realli hurt wen u need amp u dont tell take care',
#   0),
#  ('yep get program slack', 0),
#  ('cough noth', 0),
#  ('noth ever easi look reason take risk life love', 0),
#  ('hiya go sunni africa hope u r avin good time give big old silver back big kiss',
#   0),
#  ('numbr day euronumbr kickoff u kept inform latest news result daili unsubscrib send get euro stop numbr',
#   1),
#  ('hey gorgeou man work mobil number good one babe squishi mwah', 0),
#  ('feel nauseou piss eat sweet week cau today plan pig diet week hungri', 0),
#  ('pl tell nelson bb longer comin money expect aint come', 0),
#  ('hope thing went well doctor remind still need numbrgo u c littl thing left loung',
#   0),
#  ('ok cool see ya', 0),
#  ('printer cool mean groovi wine groovi', 0),
#  ('congratul thank good friend u moneysymbnumbr numbr xma prize numbr claim easi call numbr numbrp per minut bt nation rate',
#   1),
#  ('fyi take quick shower epsilon like lt gt min', 0),
#  ('hey darlin pick u colleg u tell wen numbr mt love pete xx', 0),
#  ('late said websit dont slipper', 0),
#  ('sorri earlier put fire around talk numbr actual life lol', 0),
#  ('hey tell blake address carlo want meet got lost answer phone', 0),
#  ('r ü go numbr today meet', 0),
#  ('ask numbrmobil numbr chatlin inclu free min india cust serv sed ye lnumbrer got mega bill numbr dont giv shit bailiff due day moneysymbnumbr numbr want moneysymbnumbr',
#   1),
#  ('make life stress alway find time laugh may add year life sure add life ur year gud ninumbr swt dream',
#   0),
#  ('come home class right need work shower', 0),
#  ('time come tomorrow', 0),
#  ('awak oh', 0),
#  ('sure result offer', 0),
#  ('got got numbr colour lor one colour quit light n e darker lor actual done style hair',
#   0),
#  ('today iz yellow rose day u love frndship give numbr misscal amp send ur frndz amp see mani miss call u get u get numbrmiss u marri ur lover',
#   0),
#  ('anyth special', 0),
#  ('possess especi first offen', 0),
#  ('u reach orchard alreadi u wan numbr go buy ticket first', 0),
#  ('ok everi night take warm bath drink cup milk see work magic still need loo weight know',
#   0),
#  ('alright make sure car back tonight', 0),
#  ('like think alway possibl pub later', 0),
#  ('gonna abl late notic home week anyway plan', 0),
#  ('sm servic inclu text credit pl goto www comuk net login numbrqxjnumbr unsubscrib stop extra charg help numbr comuk numbr cmnumbr numbra',
#   1),
#  ('dad went oredi', 0),
#  ('k work someth', 0),
#  ('u know watchin lido', 0),
#  ('gonna rip uteru', 0),
#  ('natalja numbr f invit friend repli ye numbr numbr see www sm ac u natnumbr stop send stop frnd numbr',
#   1),
#  ('okey dokey bit sort stuff', 0),
#  ('anytim lor', 0),
#  ('good morn repair shop reason hour', 0),
#  ('custom servic annonc new year deliveri wait plea call numbr arrang deliveri',
#   1),
#  ('realli skateboard despit fact get thrown wind bandag shit arm everi five minut',
#   0),
#  ('pure heart person wonder smile make even enemi feel guilti enemi catch world smile goodmorn amp smiley sunday',
#   0),
#  ('someon contact date servic enter phone becausethey fanci find call landlin numbr poboxnumbr wnumbrrg numbrp',
#   1),
#  ('sex ur mobil free sexi pic jordan text babe numbr everi wk get sexi celeb pocketbab co uk numbr pic numbr moneysymbnumbr wk numbr',
#   1),
#  ('thk em find wtc far weiyi goin e rest dunno yet r ur goin numbr dinner den might b abl join',
#   0),
#  ('custom place call', 0),
#  ('eatin lunch', 0),
#  ('sent scream moan bed princess', 0),
#  ('mummi boy good bad posit neg mummi made wait hmmmm', 0),
#  ('get free call', 0),
#  ('thing ape u fight death keep someth minut u let go', 0),
#  ('today vodafon number end numbr select receiv moneysymbnumbr award number match call numbr receiv moneysymbnumbr award',
#   1),
#  ('move morphin', 0),
#  ('brother geniu', 0),
#  ('hmm ill think ok forgiven', 0),
#  ('aiyar sorri lor forgot numbr tell u', 0),
#  ('oh grand bit parti mention cover charg probabl first come first serv', 0),
#  ('probabl still go stuff', 0),
#  ('u turn heater heater set lt gt degr', 0),
#  ('friendship poem dear dear u r near hear dont get fear live cheer tear u r alway dear gud ninumbr',
#   0),
#  ('thought bout drink tap spile seven pub ga st broad st canal ok', 0),
#  ('problem', 0),
#  ('hmm well night night', 0),
#  ('ok lor anyway thk cant get ticket co like quit late alreadi u wan numbr go look numbr ur fren darren wif',
#   0),
#  ('x cour numbryr messag messeng lik r send', 0),
#  ('ever green quot ever told jerri cartoon person irrit u alway one love u vri much fail express gud nyt',
#   0),
#  ('free entri moneysymbnumbr weekli comp send word win numbr numbr c www txttowin co uk',
#   1),
#  ('take someth pain move howev side next numbrhr see doctor', 0),
#  ('dear good morn feel dear', 0),
#  ('watch cartoon listen music amp eve go templ amp church u', 0),
#  ('freemsg fanci flirt repli date join uk fastest grow mobil date servic msg rcvd numbrp optout txt stop numbr repli date',
#   1),
#  ('need drug anymor', 0),
#  ('numbrnd time tri numbr contact u u numbr pound prize numbr claim easi call numbr numbrp per min bt nation rate',
#   1),
#  ('buzz hey love think hope day goe well sleep miss babe long moment togeth love smile',
#   0),
#  ('nvm take ur time', 0),
#  ('say give call friend got money definit buy end week', 0),
#  ('good afternoon boytoy goe walk day get polic abstract still wake miss babe',
#   0),
#  ('lara said loan lt gt', 0),
#  ('ok said got wisdom teeth hidden insid n mayb need numbr remov', 0),
#  ('greatest test courag earth bear defeat without lose heart gn tc', 0),
#  ('dont want hear anyth', 0),
#  ('bu way calicut', 0),
#  ('yup need ju wait numbr e rain numbr stop', 0),
#  ('tee hee lectur cheeri bye bye', 0),
#  ('practi curtsey', 0),
#  ('thnx dude u guy numbrnit', 0),
#  ('lay man let know miss thought great day send bimbo ugo number ill appreci safe',
#   0),
#  ('show wot say could u c numbr dust', 0),
#  ('numbrmth half price orang line rental latest camera phone numbr free phone numbrmth call mobilesdirect free numbr updat ornumbrstoptxt',
#   1),
#  ('hope would send messag rent due dont enough reserv complet gone loan need hope could balanc lt gt way could get till mid march hope pay back',
#   0),
#  ('like hotel dusk game think solv puzzl area thing', 0),
#  ('ard numbr lor ok messag ü lor', 0),
#  ('bring tat cd forget', 0),
#  ('wat time u finish ur lect today', 0),
#  ('e person e sm survey', 0),
#  ('okay soon best', 0),
#  ('frnd nece life imagin urself witout frnd hw u feel ur colleg wat u wth ur cell wat abt function thnk abt event esp care miss amp irrit u numbrwrd dear love frnd wthout u cant live jst takecar goodmorn',
#   0),
#  ('well littl time thing good time ahead', 0),
#  ('babe miiiiiiissssssssss need crave geeee sad without babe love', 0),
#  ('got job wipro get everi thing life numbr numbr year', 0),
#  ('abl anyth', 0),
#  ('nothin come mind ü help buy hanger lor ur laptop heavi', 0),
#  ('great princess think', 0),
#  ('think disturb da', 0),
#  ('mani peopl seem special first sight remain special till last sight maintain till life end sh ja',
#   0),
#  ('must sit around wait summer day celebr magic sight world dress white oooooh let snow',
#   0),
#  ('know someon know fanci call numbr find pobox numbr lsnumbrhb numbrp', 1),
#  ('alway yahoo messeng send messag get may send mobil mode sha get repli', 0),
#  ('yeah stand close tho catch someth', 0),
#  ('k wait chikku il send aftr lt gt min', 0),
#  ('call see facebook huh', 0),
#  ('gud ninumbr dear slp well take care swt dream muah', 0),
#  ('watch surya movi numbr pm vijay movi pokkiri', 0),
#  ('hey congrat numbrunumbr id luv numbr ive numbr go home', 0),
#  ('anyth lar', 0),
#  ('ya tel wat ur problem', 0),
#  ('alright see bit', 0),
#  ('fffff text kadeem far gone', 0),
#  ('still look job much ta earn', 0),
#  ('call say come today ok tell fool like ok', 0),
#  ('urgent numbr costa del sol holiday moneysymbnumbr await collect call numbr toclaim sae tc poboxnumbr stockport sknumbrxh costmoneysymbnumbr pm maxnumbrmin',
#   1),
#  ('haha get use drive usf man know lot stoner', 0),
#  ('get ticket numbr walsal tue numbr th march mate get sat ill pay treat want numbr go txt bak terri',
#   0),
#  ('need come home give good lovin', 0),
#  ('let know need anyth el salad desert someth mani beer shall get', 0),
#  ('busi tri finish new year look forward final meet', 0),
#  ('u horribl gal u knew dat go wif yest n u still come n ask', 0),
#  ('okay seen pick friday', 0),
#  ('give us back id proof lt gt rs wont allow work come home within day', 0),
#  ('sorri call later', 0),
#  ('sorri hurt', 0),
#  ('decemb mobil numbrmth entitl updat latest colour camera mobil free call mobil updat vco free numbr',
#   1),
#  ('come take littl time child afraid dark becom teenag want stay night', 1),
#  ('gud mrng dear hav nice day', 0),
#  ('india go draw seri mani year south african soil', 0),
#  ('want lt gt rs da', 0),
#  ('omg could snow tonit', 0),
#  ('love ass enjoy doggi style', 0),
#  ('short cute good person dont tri prove gud mrng', 0),
#  ('cmon babe make horni turn txt fantasi babe im hot sticki need repli cost moneysymbnumbr numbr cancel send stop',
#   1),
#  ('quit lor dun tell wait get complac', 0),
#  ('send email mind lt gt time per night', 0),
#  ('winner u special select numbr receiv moneysymbnumbr cash numbr holiday flight inc speak live oper numbr claim numbr',
#   1),
#  ('mum went numbr dentist', 0),
#  ('unbeliev faglord', 0),
#  ('differ style', 0),
#  ('puriti friendship two smile read forward messag smile see name gud evng musthu',
#   0),
#  ('want funk ur fone weekli new tone repli tonesnumbru numbr text www rington co uk origin n best tone numbrgbp network oper rate appli',
#   1),
#  ('plea call custom servic repr freephon numbr numbr numbr numbram numbrpm guarant moneysymbnumbr cash moneysymbnumbr prize',
#   1),
#  ('dont give monkey wot think certainli mind friend mine sleep wiv wud annoyin',
#   0),
#  ('guess want alon time could show watch', 0),
#  ('hey iouri gave number wyli ryan friend', 0),
#  ('e best numbr ur exam later', 0),
#  ('simpl arithmet percentag', 0),
#  ('littl darl far week need coff run tomo believ time week alreadi', 0),
#  ('love wine dine ladi', 0),
#  ('love give massag use lot babi oil fave posit', 0),
#  ('numbr numbrp numbr alfi moon children need song ur mob tell ur mnumbr txt tone chariti numbr nokia poli chariti poli zed numbr profit numbr chariti',
#   1),
#  ('watch tv lor', 0),
#  ('winner valu network custom hvae select receiv moneysymbnumbr reward collect call numbr valid numbr hour aclnumbrpm',
#   1),
#  ('oh haha den shld went today gee nvm la kaiez dun mind goin jazz oso scare hiphop open cant catch',
#   0),
#  ('haha leg neck kill amigo hope end night burn think could swing like hour',
#   0),
#  ('hope scare', 0),
#  ('yo yo yo byatch whassup', 0),
#  ('freemsg hey darl numbr week word back like fun still tb ok xxx std chg send moneysymbnumbr rcv',
#   1),
#  ('tirupur call da', 0),
#  ('wot wed nite numbr til numbr', 0),
#  ('forward numbr plea call numbr immedi urgent messag wait', 1),
#  ('project pa come', 0),
#  ('hey rite u put numbr evey mnth', 0),
#  ('numbr oz guy kinda flaki one friend interest pick moneysymb lt gt worth tonight possibl',
#   0),
#  ('good time nice someth bit differ weekend chang see ya soon', 0),
#  ('night sweet sleep well see exorc emili rose may never sleep hug snog', 0),
#  ('hahaha use brain dear', 0),
#  ('sen told go join uncl financ cbe', 0),
#  ('thank fill complet calm reassur', 0),
#  ('get anywh damn job hunt', 0),
#  ('haha friend tyler liter ask could get dubsack', 0),
#  ('otherwi part time job na tuition', 0),
#  ('come home numbr dinner', 0),
#  ('sent wife text buy tell relax go get wkend', 0),
#  ('give someth drink take vomit temp might drop unmit howev let know', 0),
#  ('go dinner msg', 0),
#  ('ya onion roast', 0),
#  ('see cup coff anim', 0),
#  ('like tell deepest darkest fantasi call numbr numbrp min stop text call numbr nat rate',
#   1),
#  ('monday next week give full gist', 0),
#  ('start dont stop pray good idea anyth see help guy forward link', 0),
#  ('hey mate spoke mag peopl deliv end month deliv numbrth sept talk later', 0),
#  ('dear got lt gt dollar hi hi', 0),
#  ('east coast', 0),
#  ('born god said oh anoth idiot born god said oh competit knew one day two becom freind forev',
#   0),
#  ('ur rington servic chang numbr free credit go clubnumbrmobil com choo content stop txt club stop numbr numbrp wk clubnumbr po boxnumbr mknumbr numbrwt',
#   1),
#  ('might come kerala numbr day prepar take leav finali dont plan travel visit need finish urgent work',
#   0),
#  ('ditto worri say anyth anymor like said last night whatev want peac', 0),
#  ('messag truro hospit ext phone phone side', 0),
#  ('dnt wnt tlk wid u', 0),
#  ('cthen thk shd b enuff still got conclu n content pg n refer b da content pg n cover pg',
#   0),
#  ('ya nice readi thursday', 0),
#  ('tabl occupi wait tree', 0),
#  ('wait numbr tv show numbr start lor u leh still busi ur report', 0),
#  ('relea vday shirt u put make bottom half nake instead white underwear', 0),
#  ('hey happen de alright', 0),
#  ('done mean', 0),
#  ('doubl min numbr txt orang tariff latest motorola sonyericsson nokia bluetooth free call mobileupdnumbr numbr callnumbroptout hfnumbr',
#   1),
#  ('well watch shrek numbrd b', 0),
#  ('got call landlin number ask come anna nagar go afternoon', 0),
#  ('mostli like', 0),
#  ('sorri call later', 0),
#  ('cheer callin babe sozi culdnt talkbut wannatel u detail later wenwecan chat properli x',
#   0),
#  ('hi way u numbrday normal way real ur uniqu hope know u numbr rest mylif hope u find wot lost',
#   0),
#  ('life style garment account plea', 0),
#  ('xy go numbr e lunch', 0),
#  ('last much numbr hour might get lucki', 0),
#  ('wonder co dun rem see silver car thk saw black one', 0),
#  ('gud mrng dear hav nice day', 0),
#  ('enjoy watch play footbal basketb anyth outdoor', 0),
#  ('glad talk', 0),
#  ('u subscrib best mobil content servic uk moneysymbnumbr per numbr day send stop numbr helplin numbr',
#   1),
#  ('say explicitli told nora know someon probabl gonna bother', 0),
#  ('ur award citi break could win moneysymbnumbr summer shop spree everi wk txt store numbr skilgm tscsnumbrwinawk agenumbr moneysymbnumbrperwksub',
#   1),
#  ('hello yeah got bath need hair come done yeah', 0),
#  ('plan manag', 0),
#  ('god love limit god grace measur god power boundari may u god endless bless alway ur life gud ninumbr',
#   0),
#  ('yup ok', 0),
#  ('six chanc win cash numbr numbr numbr pound txt cshnumbr send numbr cost numbrp day numbrday numbr tsandc appli repli hl numbr info',
#   1),
#  ('ü thk wat eat tonight', 0),
#  ('big brother realli scrape barrel shower social misfit', 0),
#  ('true k u knw di lt gt', 0),
#  ('haha sound crazi dunno tahan anot', 0),
#  ('urgent mobil numbr award moneysymbnumbr numbr bonu caller prize numbr numbr numbr numbrnd attempt contact call numbr numbr numbr boxnumbrqu',
#   1),
#  ('hi wkend ok journey terribl wk good huge back log mark', 0),
#  ('guess first time creat web page www asjesu com read wrote wait opinion want friend numbr numbr',
#   1),
#  ('turn phone mom tell everyon cancer sister stop call hurt talk put see u u get home love u',
#   0),
#  ('think thank see tomo', 0),
#  ('kalli wont bat numbrnd inning', 0),
#  ('batteri mr adew uncl aka egbon', 0),
#  ('sent price mean lt gt g', 0),
#  ('still chanc search hard get let tri', 0),
#  ('farm open', 0),
#  ('say bold torch later one torch numbrbold', 0),
#  ('liter bed like lt gt hour', 0),
#  ('u numbr secret admir look numbr make contact u find r reveal think ur special call numbr',
#   1),
#  ('want new video phone numbr anytim network min numbr inclu video call download numbr per week free deltomorrow call numbr repli',
#   1),
#  ('bruce amp fowler mom car park long stori', 0),
#  ('hey angri repli dr', 0),
#  ('hi sexychat girl wait text text great night chat send stop stop servic', 1),
#  ('come hill monster hope great day thing r go fine busi though', 0),
#  ('yoyyooo u know chang permiss drive mac usb flash drive', 0),
#  ('numbrmth half price orang line rental latest camera phone numbr free phone numbrmth call mobilesdirect free numbr updat ornumbrstoptxt cs',
#   1),
#  ('sorri delay ye master', 0),
#  ('start search get job day great potenti talent', 0),
#  ('know thinkin malaria relax children cant handl malaria would wor gastroent take enough replac loss temp reduc give malaria med vomit self limit ill mean day complet stop',
#   0),
#  ('win newest harri potter order phoenix book numbr repli harri answer numbr question chanc first among reader',
#   1),
#  ('better made friday stuf like pig yesterday feel bleh least writh pain kind bleh',
#   0),
#  ('cramp stop go back sleep', 0),
#  ('reach offic around lt decim gt amp mobil problem cann get voic call asa free',
#   0),
#  ('account number', 0),
#  ('swhrt u dey hope ur ok tot u numbrday love n miss take care', 0),
#  ('carlo take sweet time usual let know patti done want smoke tell haul ass',
#   0),
#  ('tick tick tick babe', 0),
#  ('alex know guy sell mid south tampa think could set like numbr', 0),
#  ('love want flood pretti pussi cum', 0),
#  ('hello handsom find job lazi work toward get back net mummi boytoy miss', 0),
#  ('ü got wat buy tell us ü need come', 0),
#  ('ok prob', 0),
#  ('well desper call armand', 0),
#  ('u knw di lt gt', 0),
#  ('winner special select receiv moneysymbnumbr cash moneysymbnumbr award speak live oper claim call numbram numbrpm cost numbrp',
#   1),
#  ('hi b ard numbr christma enjoy n merri x', 0),
#  ('winner special select receiv moneysymbnumbr cash moneysymbnumbr award speak live oper claim call numbram numbrpm cost numbrp',
#   1),
#  ('might want pull case plan spend much confid derek taylor money manag', 0),
#  ('dear hero leav qatar tonit apt opportun pl keep touch lt email gt kerala',
#   0),
#  ('hey babe sorri get sooner gari come fix cau think know go far ptbo say cost lt gt buck know might cheaper find someon second hand machin right let know want babe',
#   0),
#  ('jst chang tat', 0),
#  ('wnevr wana fal luv vth book bed fal luv vth yen madodu nav pretsorginta nammanna pretsovru import alwa gud eveb',
#   0),
#  ('think move lt gt week', 0),
#  ('sure check yahoo email sent photo yesterday', 0),
#  ('ur balanc moneysymbnumbr ur next question sang uptown girl numbr numbr answer txt ur answer numbr good luck',
#   1),
#  ('urgent call numbr landlin complementari numbr tenerif holiday moneysymbnumbr numbr cash await collect sae cs po box numbr wanumbr numbrpx numbrppm numbr sender hol offer',
#   1),
#  ('hang brother famili', 0),
#  ('ya ok dinner', 0),
#  ('wonder got onlin love gone net cafe get phone recharg friend net think boytoy',
#   0),
#  ('sorri grocer', 0),
#  ('peopl see msg think iam addict msging wrong bcoz know iam addict sweet friend bslvyl',
#   0),
#  ('hey realli pretti late want go lesson first join reach tp mrt', 0),
#  ('u want numbr meet numbrmorro', 0),
#  ('hi email address chang', 0),
#  ('gorgeou keep pix cum thank', 0),
#  ('free numbrst week nonumbr nokia tone numbr ur mob everi week txt nokia numbr get txting tell ur mate www getz co uk pobox numbr wnumbrwq normnumbrp tone numbr',
#   1),
#  ('arriv see coupl day lt numbr', 0),
#  ('tri get lost fact tee hee', 0),
#  ('k wat tht incid', 0),
#  ('xma iscom ur award either moneysymbnumbr cd gift voucher free entri numbr r moneysymbnumbr weekli draw txt music numbr tnc www ldew comnumbrwinnumbrppmxnumbragenumbrsubscript',
#   1),
#  ('gonna let know co come bak holiday day come tnumbrgetnumbrtext number', 0),
#  ('jay snicker tell x total fuck chord speak', 0),
#  ('ü still got lesson ü sch', 0),
#  ('want leav bare stay sane fight constantli help', 0),
#  ('themob check newest select content game tone gossip babe sport keep mobil fit funki text wap numbr',
#   1),
#  ('back brum thank put us keep us happi see soon', 0),
#  ('think far find check googl map place dorm', 0),
#  ('per request mell mell oru minnaminungint nurungu vettam set callertun caller press numbr copi friend callertun',
#   0),
#  ('ok let noe later n ask call u tmr', 0),
#  ('know yetund sent money yet sent text bother send dont involv anyth impo anyth first place apolog',
#   0),
#  ('tri figur suppo see coupl differ peopl week said get togeth set date', 0),
#  ('ok', 0),
#  ('food', 0),
#  ('aight well keep inform', 0),
#  ('send logo numbr ur lover numbr name join heart txt love namenumbr namenumbr mobno eg love adam eve numbr numbr yahoo poboxnumbrwnumbrwq txtno numbr ad numbrp',
#   1),
#  ('dunno da next show aft numbr numbr toa payoh got numbr', 0),
#  ('ye princess go make moan', 0),
#  ('ü noe ben go', 0),
#  ('room number wanna make sure knock right door', 0),
#  ('someon u know ask date servic numbr contact cant guess call numbr reveal po boxnumbr mnumbr numbrwu',
#   1),
#  ('lol hot air balloon', 0),
#  ('ok ask money far', 0),
#  ('de call time ill tell k', 0),
#  ('get second half messag', 0),
#  ('gud ninumbr dear slp well take care swt dream muah', 0),
#  ('ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#   0),
#  ('go noth great bye', 0),
#  ('go n buy juz buy get lar', 0),
#  ('oh rite well im best mate pete went numbr week numbrgeva longer week', 0),
#  ('guy plan come', 0),
#  ('medic mission nigeria', 0),
#  ('haiyoh mayb hamster jealou million', 0),
#  ('ok', 0),
#  ('guess could good excu lol', 0),
#  ('tunji queen wish great day abiola', 0),
#  ('dont know bring food', 0),
#  ('mmmmmm love much ahmad wait year begin everi second take closer side happi new year love',
#   0),
#  ('know grumpi old peopl mom like better lie alway one play joke', 0),
#  ('mm feel sleepi today shall get dear', 0),
#  ('oop mum somerset bit far back tomo see soon x', 0),
#  ('hey elain today meet still', 0),
#  ('host base idp linux system', 0),
#  ('regret inform u nh made mistak u never actual born plea report numbr yor local hospit numbrb termin r sorri numbr inconveni',
#   0),
#  ('aathi dear', 0),
#  ('dont flatter tell man mine two pint carlin ten minut plea', 0),
#  ('urgent ur moneysymbnumbr guarant award still unclaim call numbr closingdatenumbr numbr numbr claimcod mnumbrmnumbr moneysymbnumbrpmmorefrommobilenumbrbremov mobypoboxnumbrlsnumbryf',
#   1),
#  ('oh god gonna googl nearbi cliff', 0),
#  ('lol ouch wish stay bit longer', 0),
#  ('normal hot mail com see', 0),
#  ('tot u reach liao said shirt', 0),
#  ('sad stori man last week b day wife nt wish parent forgot n kid went work even colleagu wish enter cabin pa said happi b day boss felt special askd numbr lunch lunch invit apart went said u mind go bedroom minut ok sed sexi mood came numbr minut latr wid cake n wife parent kidz friend n colleagu scream surpri wait sofa nake',
#   0),
#  ('beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#   0),
#  ('sm servic inclu text credit pl goto www comuk net login numbrqxjnumbr unsubscrib stop extra charg help numbr comuk numbr cmnumbr numbra',
#   1),
#  ('uniqu enough find numbrth august www areyouuniqu co uk', 1),
#  ('place get room cheap', 0),
#  ('prabha soryda reali frm heart sori', 0),
#  ('haha kid papa need drug', 0),
#  ('ya one slow poo', 0),
#  ('moneysymbnumbr winner guarant caller prize final attempt contact claim call numbr numbrppmpoboxnumbrbhambnumbrx',
#   1),
#  ('heard abt tat', 0),
#  ('alrit', 0),
#  ('u secret admir look numbr make contact u find r reveal think ur special call numbr stopsm numbr',
#   1),
#  ('thank way lost', 0),
#  ('turn friend stay whole show back til lt gt feel free go ahead smoke moneysymb lt gt worth',
#   0),
#  ('good night dear sleepwel amp take care', 0),
#  ('oper lt gt', 0),
#  ('done hand know mega shop asda count celebr', 0),
#  ('sorri help', 0),
#  ('freemsg txt call numbr claim reward numbr hour talk time use phone subscribenumbrgbp mnth inc numbrhr numbr stop txtstop',
#   1),
#  ('ok much though h friday cant wait dunno wot hell im gonna anoth numbr week becom slob oh wait alreadi done',
#   0),
#  ('privat numbr account statement numbr numbr show numbr unredeem bonu point claim call numbr identifi code numbr expir numbr numbr',
#   1),
#  ('friend got say order gram got moneysymb lt gt get', 0),
#  ('normal use drink water daili', 0),
#  ('hi dear call urgnt know problem want work problem least tell wate repli',
#   0),
#  ('mayb westshor hyde park villag place near hou', 0),
#  ('open mca', 0),
#  ('chk ur belovd ms dict', 0),
#  ('heard unumbr call numbr rude chat privat line numbr cum wan numbrc pic gettin shag text pix numbr numbrend send stop numbr sam xxx',
#   1),
#  ('pick receipt someth earlier', 0),
#  ('channel', 0),
#  ('gobi art colleg', 0),
#  ('hey sathya till dint meet even singl time saw situat sathya', 0),
#  ('simpli sit watch match offic', 0),
#  ('doc prescrib morphin cau pain med enough wait mom bring med kick fast gonna tri later',
#   0),
#  ('call senthil hsbc', 0),
#  ('dear know lt gt th lt gt th birthday love gopalettan plan give small gift day like particip welcom plea contact admin team detail',
#   0),
#  ('goodmorn today late lt gt min', 0),
#  ('win year suppli cd numbr store ur choic worth moneysymbnumbr enter moneysymbnumbr weekli draw txt music numbr ts cs www ldew com subsnumbr numbrwinnumbrppmxnumbr',
#   1),
#  ('wat time r ü go xin hostel', 0),
#  ('probabl around mu lot', 0),
#  ('one interest may busi plan', 0),
#  ('ok arm feel weak cuz got shot go anoth time', 0),
#  ...]

# %%
# call find_features function for each SMS message
featuresets = [(find_features(text), label) for (text, label) in mapped]

# %%
# we can split the featuresets into training and testing datasets using sklearn
from sklearn import model_selection

# split the data into training and testing datasets
training, testing = model_selection.train_test_split(featuresets, test_size = 0.25, random_state=seed)

# %%
print(len(training))
print(len(testing))
# Out:
# 4179
# 1393

# %% [markdown]
# ### 4. Scikit-Learn Classifiers with NLTK
#
# Now that we have our dataset, we can start building algorithms! Let's start with a simple linear support vector classifier, then expand to other algorithms. We'll need to import each algorithm we plan on using from sklearn.  We also need to import some performance metrics, such as accuracy_score and classification_report.

# %%
# We can use sklearn algorithms in NLTK
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import SVC

model = SklearnClassifier(SVC(kernel = 'linear'))

# train the model on the training data
model.train(training)

# and test on the testing dataset!
accuracy = nltk.classify.accuracy(model, testing)*100
print("SVC Accuracy: {}".format(accuracy))
# Out:
# SVC Accuracy: 98.27709978463747

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Define models to train
names = ["K Nearest Neighbors", "Decision Tree", "Random Forest", "Logistic Regression", "SGD Classifier",
         "Naive Bayes", "SVM Linear"]

classifiers = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    SGDClassifier(max_iter = 100),
    MultinomialNB(),
    SVC(kernel = 'linear')
]

models = zip(names, classifiers)

for name, model in models:
    nltk_model = SklearnClassifier(model)
    nltk_model.train(training)
    accuracy = nltk.classify.accuracy(nltk_model, testing)*100
    print("{} Accuracy: {}".format(name, accuracy))
# Out:
# K Nearest Neighbors Accuracy: 94.90308686288586
# Decision Tree Accuracy: 97.05671213208902
# /home/yamshee/anaconda3/envs/RASABOT/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Random Forest Accuracy: 98.85139985642498
# /home/yamshee/anaconda3/envs/RASABOT/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression Accuracy: 98.77961234745155
# /home/yamshee/anaconda3/envs/RASABOT/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# SGD Classifier Accuracy: 98.20531227566404
# Naive Bayes Accuracy: 98.77961234745155
# SVM Linear Accuracy: 98.27709978463747

# %%
# Ensemble methods - Voting classifier
from sklearn.ensemble import VotingClassifier

names = ["K Nearest Neighbors", "Decision Tree", "Random Forest", "Logistic Regression", "SGD Classifier",
         "Naive Bayes", "SVM Linear"]

classifiers = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    SGDClassifier(max_iter = 100),
    MultinomialNB(),
    SVC(kernel = 'linear')
]

models = zip(names, classifiers)

nltk_ensemble = SklearnClassifier(VotingClassifier(estimators = list(models), voting = 'hard', n_jobs = -1))
nltk_ensemble.train(training)
accuracy = nltk.classify.accuracy(nltk_model, testing)*100
print("Voting Classifier: Accuracy: {}".format(accuracy))
# Out:
# Voting Classifier: Accuracy: 98.27709978463747

# %%
# make class label prediction for testing set
txt_features, labels = zip(*testing)

prediction = nltk_ensemble.classify_many(txt_features)

# %%
# print a confusion matrix and a classification report
print(classification_report(labels, prediction))

pd.DataFrame(
    confusion_matrix(labels, prediction),
    index = [['actual', 'actual'], ['ham', 'spam']],
    columns = [['predicted', 'predicted'], ['ham', 'spam']])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1210
#            1       0.98      0.93      0.96       183
#
#    micro avg       0.99      0.99      0.99      1393
#    macro avg       0.98      0.97      0.97      1393
# weighted avg       0.99      0.99      0.99      1393
#             predicted
#                   ham spam
# actual ham       1206    4
#        spam        12  171

# %%
confusion_matrix(labels, prediction)
# Out:
# array([[1206,    4],
#        [  12,  171]])
